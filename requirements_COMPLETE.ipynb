# %% [markdown]
# Choose only the relevants to use in the repository as a .txt file.

# %%
# !pip freeze > requirements.txt
# Out:
# WARNING: Could not generate requirement for distribution -illow 5.1.0 (c:\users\s178288\appdata\local\continuum\anaconda3\lib\site-packages): Parse error at "'-illow=='": Expected W:(abcd...)
# WARNING: Could not generate requirement for distribution -cipy 1.1.0 (c:\users\s178288\appdata\local\continuum\anaconda3\lib\site-packages): Parse error at "'-cipy==1'": Expected W:(abcd...)

# %%
# !cat requirements.txt
# Out:
# absl-py==0.4.0
# alabaster==0.7.10
# altair==4.0.1
# anaconda-client==1.6.14
# anaconda-navigator==1.8.7
# anaconda-project==0.8.2
# argh==0.26.2
# asn1crypto==0.24.0
# astor==0.7.1
# astroid==1.6.3
# astropy==3.0.2
# attrs==18.1.0
# Babel==2.5.3
# backcall==0.1.0
# backports.shutil-get-terminal-size==1.0.0
# base58==2.0.0
# beautifulsoup4==4.6.0
# bitarray==0.8.1
# bkcharts==0.2
# blaze==0.11.3
# bleach==1.5.0
# blinker==1.4
# bokeh==0.12.16
# Boruta==0.1.5
# boto==2.48.0
# boto3==1.11.3
# botocore==1.14.3
# Bottleneck==1.2.1
# category-encoders==2.1.0
# certifi==2019.11.28
# cffi==1.11.5
# chardet==3.0.4
# Click==7.0
# cloudpickle==0.5.3
# clyent==1.2.2
# colorama==0.3.9
# comtypes==1.1.4
# conda==4.8.0
# conda-build==3.10.5
# conda-package-handling==1.6.0
# conda-verify==2.0.0
# contextlib2==0.5.5
# cryptography==2.8
# cycler==0.10.0
# Cython==0.28.2
# cytoolz==0.9.0.1
# dash==0.21.1
# dash-core-components==0.23.0
# dash-html-components==0.11.0
# dask==0.17.5
# datashape==0.5.4
# deap==1.3.0
# decorator==4.3.0
# distributed==1.21.8
# dlib==19.8.1
# docutils==0.14
# entrypoints==0.2.3
# enum-compat==0.0.3
# et-xmlfile==1.0.1
# fastcache==1.0.2
# filelock==3.0.4
# Flask==0.12.2
# Flask-Compress==1.4.0
# Flask-Cors==3.0.4
# future==0.18.2
# gast==0.2.0
# gevent==1.3.0
# glob2==0.6
# greenlet==0.4.13
# grpcio==1.14.1
# h2o==3.26.0.11
# h5py==2.7.1
# heapdict==1.0.0
# html5lib==0.9999999
# idna==2.6
# imageio==2.3.0
# imagesize==1.0.0
# imutils==0.5.3
# ipykernel==5.1.3
# ipython==6.4.0
# ipython-genutils==0.2.0
# ipywidgets==7.2.1
# isort==4.3.4
# itsdangerous==0.24
# jdcal==1.4
# jedi==0.12.0
# Jinja2==2.10.3
# jmespath==0.9.4
# joblib==0.14.1
# jsonschema==2.6.0
# jupyter==1.0.0
# jupyter-client==5.2.3
# jupyter-console==5.2.0
# jupyter-contrib-core==0.3.3
# jupyter-contrib-nbextensions==0.5.1
# jupyter-core==4.4.0
# jupyter-highlight-selected-word==0.2.0
# jupyter-latex-envs==1.4.6
# jupyter-nbextensions-configurator==0.4.1
# jupyterlab==0.32.1
# jupyterlab-launcher==0.10.5
# Keras==2.1.6
# kiwisolver==1.0.1
# lazy-object-proxy==1.3.1
# lenskit==0.5.0
# lightgbm==2.2.1
# llvmlite==0.23.1
# locket==0.2.0
# lxml==4.2.1
# Markdown==2.6.11
# MarkupSafe==1.0
# matplotlib==2.2.2
# mccabe==0.6.1
# menuinst==1.4.14
# mistune==0.8.3
# mkl-fft==1.0.0
# mkl-random==1.0.1
# more-itertools==4.1.0
# mpmath==1.0.0
# msgpack-python==0.5.6
# multipledispatch==0.5.0
# navigator-updater==0.2.1
# nbconvert==5.3.1
# nbformat==4.4.0
# nbresuse==0.3.0
# networkx==2.1
# nltk==3.3
# nose==1.3.7
# notebook==5.5.0
# numba==0.38.0
# numexpr==2.6.5
# numpy==1.16.3
# numpydoc==0.8.0
# odo==0.5.1
# olefile==0.45.1
# opencv-python==4.1.2.30
# openpyxl==2.5.3
# packaging==17.1
# pandas==0.25.3
# pandocfilters==1.4.2
# parso==0.2.0
# partd==0.3.8
# path.py==11.0.1
# pathlib2==2.3.2
# pathtools==0.1.2
# patsy==0.5.0
# pep8==1.7.1
# pickleshare==0.7.4
# Pillow==7.0.0
# pkginfo==1.4.2
# plotly==4.2.1
# plotly-express==0.4.1
# pluggy==0.6.0
# ply==3.11
# preprocessor==1.1.3
# prompt-toolkit==1.0.15
# protobuf==3.6.1
# psutil==5.4.5
# py==1.5.3
# pyarrow==0.11.1
# pycodestyle==2.4.0
# pycosat==0.6.3
# pycparser==2.18
# pycrypto==2.6.1
# pycurl==7.43.0.3
# pydeck==0.2.0
# pyflakes==1.6.0
# Pygments==2.2.0
# pylint==1.8.4
# pyodbc==4.0.23
# pyOpenSSL==18.0.0
# pyparsing==2.2.0
# Pyphen==0.9.5
# PySocks==1.6.8
# pytest==3.5.1
# pytest-arraydiff==0.2
# pytest-astropy==0.3.0
# pytest-doctestplus==0.1.3
# pytest-openfiles==0.3.0
# pytest-remotedata==0.2.1
# python-dateutil==2.7.3
# pytz==2018.4
# PyWavelets==0.5.2
# pywin32==223
# pywinpty==0.5.1
# PyYAML==3.12
# pyzmq==17.0.0
# QtAwesome==0.4.4
# qtconsole==4.3.1
# QtPy==1.4.1
# requests==2.18.4
# retrying==1.3.3
# rope==0.10.7
# ruamel-yaml==0.15.35
# s3transfer==0.3.0
# scikit-image==0.13.1
# scikit-learn==0.22
# scipy==1.3.3
# seaborn==0.9.0
# Send2Trash==1.5.0
# shap==0.25.2
# simplegeneric==0.8.1
# singledispatch==3.4.0.3
# six==1.11.0
# snowballstemmer==1.2.1
# sortedcollections==0.6.1
# sortedcontainers==1.5.10
# Sphinx==1.7.4
# sphinxcontrib-websupport==1.0.1
# spotipy==2.4.4
# spyder==3.2.8
# SQLAlchemy==1.2.7
# statsmodels==0.9.0
# stopit==1.1.2
# sympy==1.1.1
# tables==3.4.3
# tabulate==0.8.6
# tblib==1.3.2
# tensorboard==1.8.0
# tensorflow==1.8.0
# termcolor==1.1.0
# terminado==0.8.1
# testpath==0.3.1
# toml==0.10.0
# toolz==0.9.0
# tornado==5.0.2
# TPOT==0.11.0
# tqdm==4.40.0
# traitlets==4.3.2
# typing==3.6.4
# tzlocal==2.0.0
# unicodecsv==0.14.1
# update-checker==0.16
# urllib3==1.22
# vaderSentiment==3.2.1
# validators==0.14.1
# watchdog==0.9.0
# wcwidth==0.1.7
# webencodings==0.5.1
# Werkzeug==0.14.1
# widgetsnbextension==3.2.1
# win-inet-pton==1.0.1
# win-unicode-console==0.5
# wincertstore==0.2
# wrapt==1.10.11
# xgboost==0.80
# xlrd==1.1.0
# XlsxWriter==1.0.4
# xlwings==0.11.8
# xlwt==1.3.0
# xmltodict==0.11.0
# zict==0.1.3

# %%
# To install requirements

#!pip install -r /path/to/requirements.txt

# !pip install --user --requirement requirements.txt
# Out:
# absl-py==0.8.0
# astor==0.8.0
# astroid==2.3.1
# astropy==3.2.1
# atomicwrites==1.3.0
# attrs==19.1.0
# backcall==0.1.0
# beautifulsoup4==4.7.1
# bleach==3.1.0
# blis==0.2.4
# bokeh==1.0.4
# boto==2.49.0
# boto3==1.9.111
# botocore==1.12.111
# branca==0.3.1
# bz2file==0.98
# cachetools==3.1.0
# certifi==2018.11.29
# chardet==3.0.4
# Click==7.0
# colorama==0.4.1
# colorlover==0.3.0
# confuse==1.0.0
# cufflinks==0.14.6
# cycler==0.10.0
# cymem==2.0.2
# cytoolz==0.9.0.1
# deap==1.3.0
# decorator==4.3.2
# defusedxml==0.5.0
# docutils==0.14
# en-core-web-sm==2.1.0
# entrypoints==0.3
# folium==0.10.0
# ftfy==4.4.3
# funcy==1.11
# future==0.17.1
# gast==0.2.2
# gensim==3.7.1
# google-pasta==0.1.7
# grpcio==1.24.1
# h5py==2.10.0
# html5lib==1.0.1
# htmlmin==0.1.12
# idna==2.8
# ijson==2.3
# imbalanced-learn==0.4.3
# imblearn==0.0
# ipykernel==5.1.0
# ipython==7.2.0
# ipython-genutils==0.2.0
# ipywidgets==7.4.2
# isort==4.3.21
# jedi==0.13.2
# jellyfish==0.7.2
# Jinja2==2.10
# jmespath==0.9.4
# joblib==0.13.2
# jsonschema==2.6.0
# jupyter==1.0.0
# jupyter-client==5.2.4
# jupyter-console==6.0.0
# jupyter-contrib-core==0.3.3
# jupyter-contrib-nbextensions==0.5.1
# jupyter-core==4.4.0
# jupyter-highlight-selected-word==0.2.0
# jupyter-latex-envs==1.4.6
# jupyter-nbextensions-configurator==0.4.1
# kaggle==1.5.3
# Keras==2.3.1
# Keras-Applications==1.0.8
# Keras-Preprocessing==1.1.0
# kiwisolver==1.0.1
# langdetect==1.0.7
# language-check==1.1
# lazy-object-proxy==1.4.2
# lenskit==0.5.0
# llvmlite==0.27.0
# lxml==4.3.2
# Markdown==3.1.1
# MarkupSafe==1.1.0
# matplotlib==3.0.2
# mccabe==0.6.1
# missingno==0.4.2
# mistune==0.8.4
# mock==2.0.0
# more-itertools==6.0.0
# murmurhash==1.0.2
# mwparserfromhell==0.5.3
# nbconvert==5.4.1
# nbformat==4.4.0
# networkx==2.3
# nltk==3.4
# nose==1.3.7
# notebook==5.7.4
# numba==0.42.0
# numexpr==2.6.9
# numpy==1.17.2
# oauthlib==3.0.1
# opencv-python==4.1.1.26
# opt-einsum==3.1.0
# packaging==19.0
# pandas==0.25.3
# pandas-profiling==2.3.0
# pandocfilters==1.4.2
# parso==0.3.3
# patsy==0.5.1
# pbr==5.1.3
# phik==0.9.8
# pickleshare==0.7.5
# Pillow==5.4.1
# plac==0.9.6
# plotly==3.6.1
# pluggy==0.9.0
# preprocessor==1.1.3
# preshed==2.0.1
# prometheus-client==0.5.0
# prompt-toolkit==2.0.8
# protobuf==3.10.0
# py==1.8.0
# pyahocorasick==1.4.0
# pyarrow==0.11.1
# pycontractions==2.0.1
# pyemd==0.5.1
# Pygments==2.3.1
# pyLDAvis==2.1.2
# pylint==2.4.2
# pyparsing==2.3.1
# Pyphen==0.9.5
# pysocks==1.7.1
# pytest==4.3.0
# pytest-pylint==0.14.1
# python-dateutil==2.7.5
# python-Levenshtein==0.12.0
# python-slugify==3.0.2
# python-twitter==3.5
# pytz==2018.9
# pywinpty==0.5.5
# PyYAML==3.13
# pyzmq==17.1.2
# qtconsole==4.5.5
# requests==2.21.0
# requests-oauthlib==1.2.0
# retrying==1.3.3
# s3transfer==0.2.0
# sacremoses==0.0.35
# scattertext==0.0.2.43
# scikit-learn==0.22
# scipy==1.3.3
# seaborn==0.9.0
# Send2Trash==1.5.0
# singledispatch==3.4.0.3
# six==1.12.0
# sklearn==0.0
# smart-open==1.8.0
# soupsieve==1.9.1
# spacy==2.1.3
# spotipy==2.4.4
# srsly==0.0.5
# statsmodels==0.9.0
# stopit==1.1.2
# tensorboard==2.0.0
# tensorflow==2.0.0
# tensorflow-estimator==2.0.0
# termcolor==1.1.0
# terminado==0.8.1
# testpath==0.4.2
# text-unidecode==1.2
# textblob==0.15.3
# textsearch==0.0.17
# thinc==7.0.4
# toolz==0.9.0
# tornado==5.1.1
# TPOT==0.11.0
# tqdm==4.40.2
# traitlets==4.3.2
# tweepy==3.5.0
# typed-ast==1.4.0
# unicode==2.7
# Unidecode==1.0.23
# update-checker==0.16
# urllib3==1.24.1
# vaderSentiment==3.2.1
# wasabi==0.2.0
# wcwidth==0.1.7
# webencodings==0.5.1
# Werkzeug==0.16.0
# widgetsnbextension==3.4.2
# wordcloud==1.5.0
# wrapt==1.11.2
# xgboost==0.82
# xlrd==1.2.0
# WARNING: Could not generate requirement for distribution -pencv-python 4.1.1.26 (c:\program files\python37\lib\site-packages): Parse error at "'-pencv-p'": Expected W:(abcd...)
