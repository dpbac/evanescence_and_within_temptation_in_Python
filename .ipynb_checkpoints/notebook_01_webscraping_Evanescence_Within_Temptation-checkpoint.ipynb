# %% [markdown]
# In this first notebook I'll apply web scraping to obtain lyrics of Evanescence and Within Temptation from the web.
#
# First, I've checked the web around for some lyrics' sites with lyrics of both bands. My goal them is to use the same code to extract lyrics for both bands.
#
# Some of the websites I've explored were
#
# - http://www.metrolyrics.com
# - https://www.azlyrics.com/
# - https://www.songteksten.nl/
# - https://www.songteksten.net/
#
# To extract hyperlinks I've used the packages:
#
# * [requests](https://pypi.org/project/requests/)
# * [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/).
#
# You will notice that some simple [Python string methods](https://www.w3schools.com/python/python_strings.asp) were used with the task of retrieving lyrics. So let's start webscraping.

# %% [markdown]
# # **Webscraping**

# %% [markdown]
# The first step is to extract addresses of links of each lyric of the band. The webpages chosen usually present title of lyrics where each title is a hyperlink to a lyric. Like this, once we have all hyperlinks, we will be able to extract each one of the lyrics using those links.
#
# The following function retrieves all hyperlinks within the main page. However, each website considered has its own particularities which must be considered when filtering out hyperlinks of the lyrics.

# %%
# importing packages

import requests
from bs4 import BeautifulSoup


def retrieve_hyperlinks(main_url):
    """ Extract all hyperlinks in 'main_url' and return a list with these hyperlinks """
    
    # Packages the request, send the request and catch the response: r

    r = requests.get(main_url)

    # Extracts the response as html: html_doc
    html_doc = r.text

    # Create a BeautifulSoup object from the HTML: soup
    soup = BeautifulSoup(html_doc,"lxml")
    
    # Find all 'a' tags (which define hyperlinks): a_tags

    a_tags = soup.find_all('a')
    
    # Create a list with hyperlinks found

    list_links = [link.get('href') for link in a_tags]
    
    # Remove none values if there is some
    
    list_links = list(filter(None, list_links)) 
    
    return list_links

# %% [markdown]
# ## Retrieving hyperlinks of lyrics
#
# Once we obtain all hyperlinks, we need to select those that contains lyrics. For now, we are investigating different lyrics' websites and each one presents a slightly different structure that must be considered when filtering out hyperlinks.
#
# By working with different websites, we can choose the one that we consider the most appropriated for extracting the lyrics.
#
# Notice that initially we will be only considering evanescence lyrics. However, as said, we have already checked that all websites considered also contain lyrics from Within Temptation. Therefore, once we have our solution, it will be applicable for both bands.

# %% [markdown]
# ### Retrieving from [metrolyrics](https://www.metrolyrics.com/)
#
# To retrieve lyrics of Evanescence from the `metrolyrics` first, we apply the above function using `main_url` = 'http://www.metrolyrics.com/evanescence-lyrics.html'.
#
# Then, as expected, we notice that not all hyperlinks are related to lyrics, so we need to filter those out and keep only the ones containing lyrics.

# %%
url = 'http://www.metrolyrics.com/evanescence-lyrics.html'
list_links_lyrics_metrolyrics = retrieve_hyperlinks(url)

# remove probable repetitions

list_links_lyrics_metrolyrics = list(set(list_links_lyrics_metrolyrics))

print('\n Number of links before filtering:', len(list_links_lyrics_metrolyrics))
list_links_lyrics_metrolyrics[:20]
# Out:
#  Number of links before filtering: 111
# ['https://www.metrolyrics.com/bring-me-to-life-lyrics-x-factor-uk.html',
#  'https://www.metrolyrics.com/the-only-one-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/evanescence-lyrics.html',
#  'https://www.metrolyrics.com/if-you-dont-mind-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/the-chain-from-gears-5-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/liquid-blue-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/even-in-death-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/bleed-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/my-heart-is-broken-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/haunted-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/rock-this-town-stray-cats-ml-video-n43.html',
#  'https://www.metrolyrics.com/lacrymosa-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/your-star-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/sallys-song-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/evanescence-news.html',
#  'https://www.metrolyrics.com/sweet-sacrifice-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/missing-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/like-you-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/the-other-side-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/news-story-grammy-awards-2020-full-list-of-winners.html']

# %% [markdown]
# A quick look in the list above reveals that links containing lyrics are of the form 'http://www.metrolyrics.com/TITLE-lyrics-evanescence.html'. So, we can select the elements of the list that contains '-lyrics-evanescence.html'.
#
# The list comprehension bellow does the job and return us 80 hyperlinks instead of the initial 111 hyperlinks.

# %%
list_links_lyrics_metrolyrics = [link for link in list_links_lyrics_metrolyrics if '-lyrics-evanescence.html' in link]
print('\n Number of links after filtering:', len(list_links_lyrics_metrolyrics))
list_links_lyrics_metrolyrics
# Out:
#  Number of links after filtering: 80
# ['https://www.metrolyrics.com/the-only-one-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/if-you-dont-mind-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/the-chain-from-gears-5-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/liquid-blue-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/even-in-death-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/bleed-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/my-heart-is-broken-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/haunted-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/lacrymosa-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/your-star-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/sallys-song-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/sweet-sacrifice-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/missing-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/like-you-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/the-other-side-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/imperfection-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/bring-me-to-life-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/tourniquet-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/erase-this-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/overture-lyrics-evanescence.html#/correction',
#  'https://www.metrolyrics.com/weight-of-the-world-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/secret-door-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/call-me-when-youre-sober-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/my-immortal-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/the-last-day-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/before-the-dawn-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/hells-angels-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/the-last-song-im-wasting-on-you-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/never-go-back-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/somebody-like-you-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/made-of-stone-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/what-you-want-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/lithium-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/end-of-the-dream-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/imaginary-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/never-was-never-will-be-everybodys-fool-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/lies-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/my-immortal-band-version-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/listen-to-the-rain-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/where-will-you-go-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/going-under-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/snow-white-queen-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/breathe-no-more-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/wash-it-all-away-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/forgive-me-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/unraveling-interlude-lyrics-evanescence.html#/correction',
#  'https://www.metrolyrics.com/for-you-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/broken-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/taking-over-me-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/cloud-nine-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/understanding-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/anywhere-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/angel-of-mine-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/fall-into-you-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/field-of-innocence-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/the-chain-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/cartoon-network-song-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/away-from-me-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/lost-whispers-intro-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/my-last-breath-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/lost-in-paradise-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/so-close-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/the-boys-of-summer-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/you-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/i-hate-everything-about-you-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/the-change-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/whisper-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/hello-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/call-me-when-youre-a-sober-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/solitude-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/good-enough-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/everybodys-fool-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/wake-me-up-inside-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/new-way-to-bleed-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/together-again-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/thoughtless-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/taking-me-over-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/october-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/somebody-like-you-lyrics-evanescence.html#/correction',
#  'https://www.metrolyrics.com/call-me-when-your-sober-lyrics-evanescence.html']

# %% [markdown]
# After filtering, we see that some links finishing with '/correction', so we update the list comprehension above to eliminate the links with '/correction'.

# %%
# updated version

list_links_lyrics_metrolyrics = [link for link in list_links_lyrics_metrolyrics if 
                                 ('-lyrics-evanescence.html' in link and '/correction' not in link)]

print('\n Number of links after updated filtering:', len(list_links_lyrics_metrolyrics))

list_links_lyrics_metrolyrics.sort()
list_links_lyrics_metrolyrics
# Out:
#  Number of links after updated filtering and applying set: 77
# ['https://www.metrolyrics.com/angel-of-mine-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/anywhere-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/away-from-me-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/before-the-dawn-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/bleed-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/breathe-no-more-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/bring-me-to-life-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/broken-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/call-me-when-your-sober-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/call-me-when-youre-a-sober-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/call-me-when-youre-sober-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/cartoon-network-song-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/cloud-nine-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/end-of-the-dream-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/erase-this-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/even-in-death-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/everybodys-fool-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/fall-into-you-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/field-of-innocence-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/for-you-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/forgive-me-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/going-under-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/good-enough-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/haunted-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/hello-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/hells-angels-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/i-hate-everything-about-you-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/if-you-dont-mind-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/imaginary-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/imperfection-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/lacrymosa-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/lies-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/like-you-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/liquid-blue-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/listen-to-the-rain-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/lithium-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/lost-in-paradise-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/lost-whispers-intro-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/made-of-stone-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/missing-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/my-heart-is-broken-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/my-immortal-band-version-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/my-immortal-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/my-last-breath-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/never-go-back-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/never-was-never-will-be-everybodys-fool-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/new-way-to-bleed-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/october-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/sallys-song-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/secret-door-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/snow-white-queen-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/so-close-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/solitude-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/somebody-like-you-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/sweet-sacrifice-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/taking-me-over-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/taking-over-me-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/the-boys-of-summer-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/the-chain-from-gears-5-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/the-chain-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/the-change-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/the-last-day-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/the-last-song-im-wasting-on-you-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/the-only-one-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/the-other-side-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/thoughtless-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/together-again-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/tourniquet-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/understanding-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/wake-me-up-inside-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/wash-it-all-away-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/weight-of-the-world-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/what-you-want-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/where-will-you-go-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/whisper-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/you-lyrics-evanescence.html',
#  'https://www.metrolyrics.com/your-star-lyrics-evanescence.html']

# %% [markdown]
# So finally, for metrolyrics we have obtained 77 hyperlinks of Evanescence's lyrics.
#
# Let's check the other websites.

# %% [markdown]
# ### Retrieving from [songteksten.net](https://songteksten.net/)
#
# This webpage presents 3 pages with links to lyrics, so we need to apply the function on all links.
#
# Before filtering we have 229 links after filtering 86. Observe that although there is apparently no repetition, there are different versions of the same music (e.g. lies and lies-remix).

# %%
# retrieving all hyperlinks
urls = ['https://songteksten.net/artist/lyrics/1938/evanescence.html',
       'https://songteksten.net/artist/lyrics/1938/evanescence/page/2.html',
       'https://songteksten.net/artist/lyrics/1938/evanescence/page/3.html']

list_links_lyrics_songteksten_net = []

for url in urls:
    list_links_lyrics_songteksten_net.extend(retrieve_hyperlinks(url))
    
# remove probable repetitions

list_links_lyrics_songteksten_net = list(set(list_links_lyrics_songteksten_net))

    
print('Number of links before filtering:', len(list_links_lyrics_songteksten_net))
# Out:
# Number of links before filtering: 229

# %%
list_links_lyrics_songteksten_net
# Out:
# ['https://songteksten.net/lyric/1938/30606/evanescence/breathe-no-more.html',
#  'https://forum.songteksten.net/index.php?topic=1327.msg86864;topicseen#new',
#  '//songteksten.net/genres.html',
#  'https://songteksten.net/albums/add/1938.html',
#  'https://songteksten.net/news/102225/marcel-van-roosmalen-verkozen-tot-republikein-van-het-jaar.html',
#  '//songteksten.net/albums.html',
#  'https://songteksten.net/artists/3.html',
#  'https://songteksten.net/artists/n.html',
#  'https://songteksten.net/lyric/1938/30586/evanescence/tourniquet.html',
#  'https://songteksten.net/info/1187/rss-api-functies.html',
#  'http://bandhosting.nl',
#  'https://songteksten.net/lyric/1938/93924/evanescence/never-go-back.html',
#  'https://songteksten.net/lyric/1938/59299/evanescence/sweet-sacrifice.html',
#  'https://songteksten.net/lyric/1938/59309/evanescence/all-that-im-living-for.html',
#  'https://songteksten.net/artists/q.html',
#  'https://songteksten.net/lyric/9019/102741/snelle/smoorverliefd.html',
#  'https://songteksten.net/lyric/1938/65087/evanescence/thoughtless.html',
#  'https://songteksten.net/artist/lyrics/8941/future.html',
#  'https://songteksten.net/artists/u.html',
#  'https://songteksten.net/artist/lyrics/4166/earth-wind-and-fire.html',
#  'https://songteksten.net/artists/g.html',
#  'https://songteksten.net/artist/lyrics/1938/evanescence/page/1.html',
#  'https://songteksten.net/artist/lyrics/1938/evanescence.html',
#  'https://songteksten.net/lyric/1938/74262/evanescence/the-last-song-im-wasting-on-you.html',
#  'https://songteksten.net/lyric/1938/30589/evanescence/hello.html',
#  'https://songteksten.net/lyric/1938/32041/evanescence/listen-to-the-rain.html',
#  'https://songteksten.net/artist/lyrics/232/rammstein.html',
#  '//songteksten.net/lyrics/popular.html',
#  'https://songteksten.net/artist/translations/1938/evanescence.html',
#  'https://songteksten.net/editors/signup/1938.html',
#  'https://songteksten.net/albums/album/7419/2305/niels-destadsbader/speeltijd.html',
#  'https://songteksten.net/lyric/1938/74649/evanescence/wash-it-all-away.html',
#  'https://forum.songteksten.net/index.php?topic=1327.msg86861;topicseen#new',
#  'https://songteksten.net/lyric/9019/102217/snelle/reunie.html',
#  'https://songteksten.net/lyric/1938/50255/evanescence/forever-gone-forever-you.html',
#  '/',
#  '//songteksten.net/artists.html',
#  'https://songteksten.net/lyric/1938/92310/evanescence/my-heart-is-broken.html',
#  'https://songteksten.net/albums/album/8117/2300/ed-sheeran/no-6-collaborations-project.html',
#  'https://songteksten.net/lyric/1938/93938/evanescence/secret-door.html',
#  'https://songteksten.net/lyric/60/96869/marco-borsato/samen-voor-altijd.html',
#  'https://songteksten.net/lyric/1938/46791/evanescence/anything-for-you.html',
#  'https://songteksten.net/artists/a.html',
#  'https://songteksten.net/lyric/1938/30603/evanescence/forgive-me.html',
#  'https://songteksten.net/artists/2.html',
#  'https://songteksten.net/lyric/1938/93921/evanescence/end-of-the-dream.html',
#  'https://songteksten.net/artists/l.html',
#  'https://songteksten.net/lyric/9173/102289/tones-and-i/dance-monkey.html',
#  'https://songteksten.net/lyric/1938/30596/evanescence/lies.html',
#  'https://songteksten.net/lyric/1938/40741/evanescence/before-the-dawn.html',
#  'https://songteksten.net/artists/z.html',
#  '//songteksten.net/translations/popular.html',
#  'https://songteksten.net/lyric/1938/30581/evanescence/going-under.html',
#  'https://songteksten.net/artist/lyrics/2047/nena.html',
#  'https://songteksten.net/news/102228/beach-boys-frontman-roept-op-tot-boycot-beach-boys-concert.html',
#  'https://songteksten.net/lyric/8962/102762/merol/slippertje.html',
#  'https://songteksten.net/lyric/1938/30600/evanescence/so-close.html',
#  'https://songteksten.net/artists/6.html',
#  'https://songteksten.net/artist/lyrics/9247/niks-aan-de-zeis.html',
#  'https://songteksten.net/lyric/1938/48349/evanescence/heart-shaped-box.html',
#  'https://songteksten.net/artist/lyrics/7419/niels-destadsbader.html',
#  'https://songteksten.net/lyric/1938/30598/evanescence/goodnight.html',
#  '//forum.songteksten.net',
#  'https://songteksten.net/lyric/1938/59301/evanescence/lithium.html',
#  'https://forum.songteksten.net/index.php?topic=1327.msg86860;topicseen#new',
#  'https://songteksten.net/artists/4.html',
#  '//forum.songteksten.net/index.php?action=login',
#  'https://songteksten.net/artist/lyrics/1938/evanescence/page/3.html',
#  'https://songteksten.net/lyric/9173/102759/tones-and-i/never-seen-the-rain.html',
#  'https://songteksten.net/lyric/9247/102765/niks-aan-de-zeis/met-de-trekker-naar-s-gravenhage.html',
#  'https://songteksten.net/artist/lyrics/8962/merol.html',
#  'https://songteksten.net/artist/lyrics/8957/billie-eilish.html',
#  'https://songteksten.net/lyric/add/1938.html',
#  'https://songteksten.net/artists/d.html',
#  'https://songteksten.net/adverteren.html',
#  'https://songteksten.net/lyric/8957/102758/billie-eilish/xanny.html',
#  'https://songteksten.net/artists/h.html',
#  'https://songteksten.net/lyric/1938/31324/evanescence/you-dont-have-to-cry.html',
#  'https://songteksten.net/lyric/1938/30602/evanescence/give-unto-me.html',
#  'https://songteksten.net/lyric/1938/30609/evanescence/bring-me-to-life.html',
#  'https://songteksten.net/artists/f.html',
#  'https://songteksten.net/artist/lyrics/2881/maroon-5.html',
#  'https://songteksten.net/albums/album/1938/344/evanescence/anywhere-but-home.html',
#  'https://songteksten.net/news/97302/within-temptation-en-evanescence-samen-op-tournee.html',
#  'https://songteksten.net/info/1185/over-ons.html',
#  'https://songteksten.net/lyric/9049/101801/danny-vera/roller-coaster.html',
#  'https://songteksten.net/lyric/7419/102761/niels-destadsbader/hoofd-op-mijn-schouder.html',
#  'https://songteksten.net/lyric/1938/59305/evanescence/like-you.html',
#  'https://songteksten.net/lyric/1938/30593/evanescence/fields-of-innocence.html',
#  '//songteksten.net',
#  'https://forum.songteksten.net/index.php?topic=3543.msg86862;topicseen#new',
#  'https://songteksten.net/lyric/1938/45002/evanescence/imaginary.html',
#  'https://songteksten.net/artist/downloads/1938/evanescence.html',
#  'https://songteksten.net/artists/7.html',
#  'https://songteksten.net/lyric/1938/93939/evanescence/the-other-side.html',
#  'https://songteksten.net/lyric/1938/59304/evanescence/lacrymosa.html',
#  'https://songteksten.net/lyric/1938/93937/evanescence/say-you-will.html',
#  'https://songteksten.net/news/97627/extra-show-van-within-temptation-en-evanescence-in-amsterdam.html',
#  'https://songteksten.net/lyric/1938/30592/evanescence/where-will-you-go.html',
#  'https://songteksten.net/lyric/1938/59308/evanescence/your-star.html',
#  'https://songteksten.net/albums/album/7419/2306/niels-destadsbader/speeltijd-niels-wiels-editie.html',
#  'https://forum.songteksten.net/index.php?topic=1327.msg86865;topicseen#new',
#  'https://songteksten.net/albums/album/7419/2310/niels-destadsbader/boven-de-wolken-fan-editie.html',
#  'https://songteksten.net/lyric/1938/93934/evanescence/sick.html',
#  'https://songteksten.net/albums/album/7902/2304/kensington/time.html',
#  'https://songteksten.net/lyric/1938/33820/evanescence/surrender.html',
#  'https://songteksten.net/artist/lyrics/9049/danny-vera.html',
#  'https://songteksten.net/lyric/1938/93923/evanescence/new-way-to-bleed.html',
#  'https://songteksten.net/lyric/1938/30604/evanescence/exodus.html',
#  'https://songteksten.net/lyric/1938/30594/evanescence/even-in-death.html',
#  'https://songteksten.net/lyric/1938/41509/evanescence/restless.html',
#  'https://songteksten.net/lyric/1938/31716/evanescence/you.html',
#  'https://songteksten.net/lyric/1938/87754/evanescence/wake-me-up-inside-bring-me-to-life.html',
#  'https://songteksten.net/artists/1.html',
#  'https://songteksten.net/artists/w.html',
#  'https://songteksten.net/profile/view/33726/survivor.html',
#  '//songteksten.net/lyric/add.html',
#  'https://songteksten.net/lyric/1938/30588/evanescence/taking-over-me.html',
#  'https://songteksten.net/artists/8.html',
#  'https://songteksten.net/news/102223/madonna-biedt-harry-en-meghan-appartement-aan.html',
#  'https://songteksten.net/lyric/1938/48348/evanescence/fall-into-you.html',
#  'https://songteksten.net/albums/album/1938/171/evanescence/fallen.html',
#  'https://songteksten.net/artist/albums/1938/evanescence.html',
#  'https://songteksten.net/artist/lyrics/9217/emma-heesters.html',
#  'https://songteksten.net/albums/album/232/2299/rammstein/rammstein.html',
#  'https://songteksten.net/lyric/1938/30585/evanescence/haunted.html',
#  'https://songteksten.net/lyric/1938/73657/evanescence/lies-remix.html',
#  'https://songteksten.net/artist/lyrics/9019/snelle.html',
#  '//songteksten.net/videos.html',
#  'https://songteksten.net/artists/s.html',
#  'https://songteksten.net/news/102219/tom-jones-viert-tachtigste-verjaardag-in-ziggo-dome.html',
#  'https://songteksten.net/lyric/1938/59310/evanescence/good-enough.html',
#  'https://songteksten.net/info/1186/privacy.html',
#  'https://songteksten.net/lyric/8601/102664/maan/ze-huilt-maar-ze-lacht.html',
#  'https://songteksten.net/lyric/1938/30591/evanescence/whisper.html',
#  'https://songteksten.net/artists/c.html',
#  'https://songteksten.net/artists/e.html',
#  'https://songteksten.net/news/102224/veel-annuleringen-bij-meilandjes-na-verhuisbericht.html',
#  'https://songteksten.net/lyric/1938/59306/evanescence/lose-control.html',
#  'https://songteksten.net/lyric/1938/30601/evanescence/understanding-wash-it-all-away.html',
#  'https://songteksten.net/artist/lyrics/2543/drake.html',
#  'https://songteksten.net/artists/j.html',
#  'https://songteksten.net/lyric/1938/93920/evanescence/erase-this.html',
#  'https://songteksten.net/',
#  'https://songteksten.net/artists/v.html',
#  'https://songteksten.net/lyric/2543/102756/drake/life-is-good.html',
#  'https://songteksten.net/lyric/1938/52535/evanescence/haunting-you.html',
#  'https://songteksten.net/lyric/1938/30582/evanescence/everybodys-fool.html',
#  'https://songteksten.net/artists/x.html',
#  'https://songteksten.net/lyric/1938/30608/evanescence/solitude.html',
#  'https://songteksten.net/news/102226/organisatie-we-are-electric-slaat-jaar-over.html',
#  'https://songteksten.net/artist/lyrics/9173/tones-and-i.html',
#  'https://songteksten.net/lyric/5943/102763/demi-lovato/anyone.html',
#  'https://songteksten.net/lyric/1938/91880/evanescence/what-you-want.html',
#  'https://songteksten.net/albums/album/4166/2298/earth-wind-and-fire/i-am.html',
#  'https://songteksten.net/artist/lyrics/5943/demi-lovato.html',
#  'https://songteksten.net/lyric/1938/31715/evanescence/i-believe-in-you.html',
#  'https://songteksten.net/lyric/1938/59307/evanescence/the-only-one.html',
#  'https://songteksten.net/artist/lyrics/9245/donnie.html',
#  'https://songteksten.net/lyric/1938/30605/evanescence/farther-away.html',
#  'https://songteksten.net/news/102220/armin-van-buuren-na-drie-jaar-weer-afsluiter-op-mysteryland.html',
#  'https://songteksten.net/artist/lyrics/545/frans-bauer.html',
#  'https://songteksten.net/lyric/3051/102764/samson-en-gert/samson-marie.html',
#  'https://songteksten.net/artists/b.html',
#  'https://songteksten.net/artist/lyrics/9064/rolf-sanchez.html',
#  '//songteksten.net/translations/latest.html',
#  'http://www.evanescence.com/',
#  'https://songteksten.net/lyric/1938/30584/evanescence/my-immortal.html',
#  'https://songteksten.net/artists/9.html',
#  'https://songteksten.net/artist/lyrics/8601/maan.html',
#  'https://songteksten.net/lyric/2047/31578/nena/99-luftballons.html',
#  'https://songteksten.net/lyric/1938/48350/evanescence/zero.html',
#  'https://songteksten.net/artists/t.html',
#  'https://songteksten.net/lyric/1938/93936/evanescence/swimming-home.html',
#  'https://songteksten.net/lyric/1938/39243/evanescence/broken.html',
#  'https://songteksten.net/lyric/1938/59300/evanescence/weight-of-the-world.html',
#  'https://songteksten.net/artist/lyrics/60/marco-borsato.html',
#  'https://songteksten.net/lyric/9064/102577/rolf-sanchez/pa-olvidarte.html',
#  'https://songteksten.net/lyric/1938/59302/evanescence/cloud-nine.html',
#  'https://songteksten.net/lyric/1938/92309/evanescence/the-end.html',
#  'https://songteksten.net/lyric/1938/73582/evanescence/4th-of-july.html',
#  'https://songteksten.net/artist/lyrics/7902/kensington.html',
#  'https://songteksten.net/lyric/1938/32518/evanescence/i-must-be-dreaming.html',
#  'https://songteksten.net/artists/y.html',
#  'https://songteksten.net/lyric/1938/59303/evanescence/snow-white-queen.html',
#  'https://songteksten.net/artist/lyrics/3051/samson-en-gert.html',
#  'https://songteksten.net/news/102222/justin-bieber-noemt-vroegere-drugsgebruik-echt-doodeng.html',
#  'https://songteksten.net/lyric/1938/93922/evanescence/made-of-stone.html',
#  'https://songteksten.net/lyric/1938/74589/evanescence/where-will-you-go-ep-version.html',
#  'https://songteksten.net/lyric/1938/83436/evanescence/together-again.html',
#  'https://songteksten.net/lyric/8941/102757/future/mask-off.html',
#  'https://songteksten.net/artist/lyrics/7846/tim-akkerman.html',
#  'https://songteksten.net/artists/o.html',
#  'https://songteksten.net/lyric/1938/58354/evanescence/call-me-when-youre-sober.html',
#  'https://songteksten.net/lyric/1938/30607/evanescence/missing.html',
#  'https://songteksten.net/lyric/1938/77101/evanescence/bleed.html',
#  'https://songteksten.net/lyric/1938/30590/evanescence/my-last-breath.html',
#  'https://songteksten.net/lyric/60/98333/marco-borsato/mooi.html',
#  'https://songteksten.net/artist/lyrics/8117/ed-sheeran.html',
#  'https://songteksten.net/albums/album/7419/2308/niels-destadsbader/boven-de-wolken.html',
#  'https://songteksten.net/artists/5.html',
#  'https://songteksten.net/lyric/1938/77224/evanescence/angel-of-mine.html',
#  'https://songteksten.net/lyric/1938/92371/evanescence/lost-in-paradise.html',
#  'https://songteksten.net/lyric/1938/30597/evanescence/away-from-me.html',
#  'https://songteksten.net/genres/genre/0.html',
#  '#',
#  'https://songteksten.net/news/102227/shannen-doherty-weer-gediagnosticeerd-met-kanker.html',
#  '//songteksten.net/lyrics/latest.html',
#  'https://songteksten.net/albums/album/7419/2307/niels-destadsbader/dertig.html',
#  'https://songteksten.net/artist/lyrics/1938/evanescence/page/2.html',
#  'https://songteksten.net/lyric/1938/93940/evanescence/the-change.html',
#  'https://songteksten.net/albums/album/1938/864/evanescence/the-open-door.html',
#  'https://songteksten.net/artists/m.html',
#  'https://songteksten.net/artists/r.html',
#  'https://songteksten.net/lyric/1938/30595/evanescence/anywhere.html',
#  'https://songteksten.net/artists/i.html',
#  'https://songteksten.net/artists/k.html',
#  'https://songteksten.net/news/102221/tommie-christiaan-in-zwart-gat-na-winnen-dancing-on-ice.html',
#  'https://songteksten.net/lyric/545/102760/frans-bauer/geen-centen-maar-spullen.html',
#  'https://songteksten.net/lyric/1938/30599/evanescence/october.html',
#  'https://songteksten.net/lyric/1938/77210/evanescence/my-cartoon-network.html',
#  'https://songteksten.net/lyric/1938/37965/evanescence/the-last-day.html',
#  'https://songteksten.net/lyric/2881/102433/maroon-5/memories.html',
#  'https://songteksten.net/lyric/1938/93919/evanescence/disappear.html',
#  'https://songteksten.net/lyric/1938/32033/evanescence/must-be-dreaming.html',
#  'https://songteksten.net/lyric/1938/100302/evanescence/imperfection.html',
#  '//songteksten.net/albums/add.html',
#  'https://songteksten.net/albums/album/7846/2302/tim-akkerman/lions-dont-cry.html',
#  'https://songteksten.net/artists/p.html']

# %% [markdown]
# In this case, to obtain lyrics we need to keep links that contain '/songteksten.net/lyric/1938' which will do by extracting the information from the url address.

# %%
# using url address to filter lyrics

spliting = urls[0].split('/')
filter_lyrics = spliting[2]+'/lyric/'+spliting[-2]

list_links_lyrics_songteksten_net = [link for link in list_links_lyrics_songteksten_net if (filter_lyrics 
                                                                              in link) ]

print('Number of links after filtering:', len(list_links_lyrics_songteksten_net))
# Out:
# Number of links after filtering: 86

# %%
#Extracting the titles of the song and rearranging in alphabetical order for quick inspection

list_titles = [link.split('/')[-1].split('.')[-2] for link in list_links_lyrics_songteksten_net ]
list_titles.sort()
list_titles
# Out:
# ['4th-of-july',
#  'all-that-im-living-for',
#  'angel-of-mine',
#  'anything-for-you',
#  'anywhere',
#  'away-from-me',
#  'before-the-dawn',
#  'bleed',
#  'breathe-no-more',
#  'bring-me-to-life',
#  'broken',
#  'call-me-when-youre-sober',
#  'cloud-nine',
#  'disappear',
#  'end-of-the-dream',
#  'erase-this',
#  'even-in-death',
#  'everybodys-fool',
#  'exodus',
#  'fall-into-you',
#  'farther-away',
#  'fields-of-innocence',
#  'forever-gone-forever-you',
#  'forgive-me',
#  'give-unto-me',
#  'going-under',
#  'good-enough',
#  'goodnight',
#  'haunted',
#  'haunting-you',
#  'heart-shaped-box',
#  'hello',
#  'i-believe-in-you',
#  'i-must-be-dreaming',
#  'imaginary',
#  'imperfection',
#  'lacrymosa',
#  'lies',
#  'lies-remix',
#  'like-you',
#  'listen-to-the-rain',
#  'lithium',
#  'lose-control',
#  'lost-in-paradise',
#  'made-of-stone',
#  'missing',
#  'must-be-dreaming',
#  'my-cartoon-network',
#  'my-heart-is-broken',
#  'my-immortal',
#  'my-last-breath',
#  'never-go-back',
#  'new-way-to-bleed',
#  'october',
#  'restless',
#  'say-you-will',
#  'secret-door',
#  'sick',
#  'snow-white-queen',
#  'so-close',
#  'solitude',
#  'surrender',
#  'sweet-sacrifice',
#  'swimming-home',
#  'taking-over-me',
#  'the-change',
#  'the-end',
#  'the-last-day',
#  'the-last-song-im-wasting-on-you',
#  'the-only-one',
#  'the-other-side',
#  'thoughtless',
#  'together-again',
#  'tourniquet',
#  'understanding-wash-it-all-away',
#  'wake-me-up-inside-bring-me-to-life',
#  'wash-it-all-away',
#  'weight-of-the-world',
#  'what-you-want',
#  'where-will-you-go',
#  'where-will-you-go-ep-version',
#  'whisper',
#  'you',
#  'you-dont-have-to-cry',
#  'your-star',
#  'zero']

# %% [markdown]
# ### Retrieving from [songteksten.nl](https://www.songteksten.nl/)
#
# Similarly, to songteksten.net we have multiple pages with hyperlinks.

# %%
# retrieving all hyperlinks
urls = ['https://www.songteksten.nl/artiest/4713/evanescence.htm',
       'https://www.songteksten.nl/artiest/4713/2/evanescence.htm']


list_links_lyrics_songteksten_nl = []

for url in urls:
    list_links_lyrics_songteksten_nl.extend(retrieve_hyperlinks(url))
    
# removing probable repetitions
list_links_lyrics_songteksten_nl = list(set(list_links_lyrics_songteksten_nl))
    
print('Number of links before filtering:', len(list_links_lyrics_songteksten_nl))
# Out:
# Number of links before filtering: 128

# %%
list_links_lyrics_songteksten_nl
# Out:
# ['/songteksten/41311/evanescence/haunted.htm',
#  'https://www.twitter.com/songtekstennl',
#  '/top45',
#  '/songteksten/67507/evanescence/good-enough.htm',
#  '/songteksten/67698/evanescence/sweet-sacrafice.htm',
#  '/songteksten/74928/evanescence/lynn.htm',
#  '/songteksten/42848/evanescence/forgive-me.htm',
#  '/songteksten/41308/evanescence/farther-away.htm',
#  '/songteksten/45785/evanescence/4th-of-july.htm',
#  '/index.php',
#  '/songteksten/48713/evanescence/bleed.htm',
#  '/songteksten/45370/evanescence/goodnite.htm',
#  '/songteksten/41313/evanescence/i-believe-in-you.htm',
#  '/songteksten/43242/evanescence/surrender.htm',
#  '/songteksten/88807/evanescence/together-again.htm',
#  '/songteksten/43243/evanescence/anything-for-you.htm',
#  '/browse/e.htm',
#  '/songteksten/41319/evanescence/wake-me-up-inside.htm',
#  '/songteksten/67510/evanescence/lithium.htm',
#  '/songteksten/53789/evanescence/solitude.htm',
#  '/',
#  '/songteksten/43906/evanescence/away-from-me.htm',
#  '/songteksten/67513/evanescence/sweet-sacrifice.htm',
#  '/songteksten/44308/evanescence/breathe-no-more.htm',
#  '/songteksten/50229/evanescence/you-amy-lee-solo-.htm',
#  '/songteksten/50227/evanescence/fallen.htm',
#  '/songteksten/367425/evanescence/do-what-you-want.htm',
#  '/songteksten/795423/evanescence/oceans.htm',
#  '/songteksten/49746/evanescence/missing--not-for-your-ears-.htm',
#  '/songteksten/41309/evanescence/fields-of-innocence.htm',
#  '/search',
#  '/songteksten/43026/evanescence/can-t-wash-it-all-away.htm',
#  '/songteksten/74925/evanescence/angel-of-mine.htm',
#  '/songteksten/363714/evanescence/new-way-to-bleed.htm',
#  '/songteksten/43023/evanescence/where-will-you-go.htm',
#  '/songteksten/795871/evanescence/secret-door.htm',
#  '/songteksten/47280/evanescence/october.htm',
#  '/songteksten/67506/evanescence/cloud-nine.htm',
#  '/songteksten/174663/evanescence/demise.htm',
#  '/songteksten/43246/evanescence/before-the-dawn.htm',
#  '/songteksten/41310/evanescence/going-under.htm',
#  '/songteksten/174660/evanescence/origin.htm',
#  '/songteksten/47539/evanescence/real-life.htm',
#  '/songteksten/67516/evanescence/your-star.htm',
#  '/songteksten/67512/evanescence/snow-white-queen.htm',
#  '/songteksten/67514/evanescence/the-only-one.htm',
#  '/songteksten/846609/evanescence/all-that-i-am-living-for.htm',
#  '/songteksten/53790/evanescence/orestes--a-perfect-circle-.htm',
#  '/songteksten/795426/evanescence/the-other-side.htm',
#  '/keuze',
#  '/songteksten/795425/evanescence/lost-in-paradise.htm',
#  '/songteksten/361700/evanescence/say-you-will.htm',
#  '/songteksten/174658/evanescence/goodnight.htm',
#  '/songteksten/41305/evanescence/bring-me-to-life.htm',
#  '/songteksten/68458/evanescence/cartoon-network.htm',
#  '/songteksten/890454/evanescence/the-end-of-the-dream.htm',
#  '/songteksten/360153/evanescence/holding-my-last-breathe.htm',
#  '/songteksten/67515/evanescence/weight-of-the-world.htm',
#  '/songteksten/53025/evanescence/thoughless.htm',
#  '/songteksten/41307/evanescence/exodus--demo-.htm',
#  '/songteksten/53438/evanescence/feel-for-you.htm',
#  '/songteksten/795872/evanescence/disappear.htm',
#  '/songteksten/43244/evanescence/understanding.htm',
#  '/songteksten/360788/evanescence/my-heart-is-broken.htm',
#  '/songteksten/45472/evanescence/give-unto-me.htm',
#  '/songteksten/174661/evanescence/field-of-innocence.htm',
#  '/songteksten/174662/evanescence/eternal.htm',
#  '/songteksten/43024/evanescence/anywhere.htm',
#  '/songteksten/889460/evanescence/imperfection.htm',
#  '/songteksten/67732/evanescence/lacrymose.htm',
#  '/songteksten/360750/evanescence/made-of-stone-.htm',
#  '/songteksten/41318/evanescence/tourniquet.htm',
#  '/songteksten/74929/evanescence/the-last-song-i-m-wasting-on-you.htm',
#  '/songteksten/41306/evanescence/everybody-s-fool.htm',
#  '/songteksten/67511/evanescence/lose-control.htm',
#  '/songteksten/994425/evanescence/the-in-between--piano-solo-.htm',
#  '/artiest/4713/evanescence.htm',
#  '/songteksten/67509/evanescence/like-you.htm',
#  '/artiest/4713/2/evanescence.htm',
#  '/songteksten/890455/evanescence/hi-lo.htm',
#  '/songteksten/43245/evanescence/missing.htm',
#  '/songteksten/43907/evanescence/the-last-day.htm',
#  '/songteksten/360416/evanescence/what-you-want.htm',
#  '/songteksten/67504/evanescence/all-that-i-m-living-for.htm',
#  '/songteksten/56458/evanescence/wisper.htm',
#  '/songteksten/41320/evanescence/whisper.htm',
#  '/songteksten/66131/evanescence/my-tourniquet.htm',
#  '/songteksten/67508/evanescence/lacrymosa.htm',
#  '/artiest/4713/evanescence',
#  '/songteksten/45786/evanescence/thoughtless.htm',
#  '/songteksten/360790/evanescence/the-change.htm',
#  '/songteksten/43025/evanescence/i-must-be-dreaming.htm',
#  '/songteksten/49240/evanescence/forever-gone-forever-you.htm',
#  '/songteksten/795424/evanescence/sick.htm',
#  '/songteksten/994419/evanescence/overture.htm',
#  '/songteksten/42850/evanescence/imaginary.htm',
#  '/songteksten/74926/evanescence/imaginery.htm',
#  '/songteksten/74927/evanescence/jealous.htm',
#  '/songteksten/45471/evanescence/so-close.htm',
#  '/songteksten/174664/evanescence/ascension-of-the-spirit.htm',
#  '/songteksten/41321/evanescence/you.htm',
#  '/songteksten/48712/evanescence/you--amy-lee-solo-.htm',
#  '/songteksten/795870/evanescence/on-the-songs%3a-lost-in-paradise.htm',
#  '/songteksten/45011/evanescence/broken.htm',
#  '/songteksten/41812/evanescence/even-in-death.htm',
#  '/songteksten/41315/evanescence/my-immortal.htm',
#  '/songteksten/45787/evanescence/zero.htm',
#  '/songteksten/795421/evanescence/swimming-home.htm',
#  'http://www.facebook.com/songteksten',
#  '/songteksten/48711/evanescence/forever.htm',
#  '/songteksten/41317/evanescence/taking-over-me.htm',
#  '/songteksten/795422/evanescence/never-go-back.htm',
#  '/songteksten/360165/evanescence/sally-s-song.htm',
#  '/songteksten/49745/evanescence/heart-shaped-box.htm',
#  '#',
#  'http://www.google.com/+songteksten',
#  '/privacy.pdf',
#  '/songteksten/48710/evanescence/exodus.htm',
#  '/songteksten/174659/evanescence/the-end.htm',
#  '/songteksten/362685/evanescence/erase-this.htm',
#  '/songteksten/891173/evanescence/bring-me-to-life--synthesis-.htm',
#  '/songteksten/41312/evanescence/hello.htm',
#  '/artiest/4713/video/evanescence.htm',
#  '/songteksten/42849/evanescence/lies.htm',
#  '/songteksten/41316/evanescence/my-last-breath.htm',
#  '/songteksten/add',
#  '/songteksten/67505/evanescence/call-me-when-you-re-sober.htm',
#  '/songteksten/45470/evanescence/listen-to-the-rain.htm']

# %%
# Only keeping the hyperlinks of the lyrics

list_links_lyrics_songteksten_nl = [link for link in list_links_lyrics_songteksten_nl 
                                    if ('/evanescence/' in link) ]

len(list_links_lyrics_songteksten_nl)
# Out:
# 112

# %%
list_links_lyrics_songteksten_nl
# Out:
# ['/songteksten/41311/evanescence/haunted.htm',
#  '/songteksten/67507/evanescence/good-enough.htm',
#  '/songteksten/67698/evanescence/sweet-sacrafice.htm',
#  '/songteksten/74928/evanescence/lynn.htm',
#  '/songteksten/42848/evanescence/forgive-me.htm',
#  '/songteksten/41308/evanescence/farther-away.htm',
#  '/songteksten/45785/evanescence/4th-of-july.htm',
#  '/songteksten/48713/evanescence/bleed.htm',
#  '/songteksten/45370/evanescence/goodnite.htm',
#  '/songteksten/41313/evanescence/i-believe-in-you.htm',
#  '/songteksten/43242/evanescence/surrender.htm',
#  '/songteksten/88807/evanescence/together-again.htm',
#  '/songteksten/43243/evanescence/anything-for-you.htm',
#  '/songteksten/41319/evanescence/wake-me-up-inside.htm',
#  '/songteksten/67510/evanescence/lithium.htm',
#  '/songteksten/53789/evanescence/solitude.htm',
#  '/songteksten/43906/evanescence/away-from-me.htm',
#  '/songteksten/67513/evanescence/sweet-sacrifice.htm',
#  '/songteksten/44308/evanescence/breathe-no-more.htm',
#  '/songteksten/50229/evanescence/you-amy-lee-solo-.htm',
#  '/songteksten/50227/evanescence/fallen.htm',
#  '/songteksten/367425/evanescence/do-what-you-want.htm',
#  '/songteksten/795423/evanescence/oceans.htm',
#  '/songteksten/49746/evanescence/missing--not-for-your-ears-.htm',
#  '/songteksten/41309/evanescence/fields-of-innocence.htm',
#  '/songteksten/43026/evanescence/can-t-wash-it-all-away.htm',
#  '/songteksten/74925/evanescence/angel-of-mine.htm',
#  '/songteksten/363714/evanescence/new-way-to-bleed.htm',
#  '/songteksten/43023/evanescence/where-will-you-go.htm',
#  '/songteksten/795871/evanescence/secret-door.htm',
#  '/songteksten/47280/evanescence/october.htm',
#  '/songteksten/67506/evanescence/cloud-nine.htm',
#  '/songteksten/174663/evanescence/demise.htm',
#  '/songteksten/43246/evanescence/before-the-dawn.htm',
#  '/songteksten/41310/evanescence/going-under.htm',
#  '/songteksten/174660/evanescence/origin.htm',
#  '/songteksten/47539/evanescence/real-life.htm',
#  '/songteksten/67516/evanescence/your-star.htm',
#  '/songteksten/67512/evanescence/snow-white-queen.htm',
#  '/songteksten/67514/evanescence/the-only-one.htm',
#  '/songteksten/846609/evanescence/all-that-i-am-living-for.htm',
#  '/songteksten/53790/evanescence/orestes--a-perfect-circle-.htm',
#  '/songteksten/795426/evanescence/the-other-side.htm',
#  '/songteksten/795425/evanescence/lost-in-paradise.htm',
#  '/songteksten/361700/evanescence/say-you-will.htm',
#  '/songteksten/174658/evanescence/goodnight.htm',
#  '/songteksten/41305/evanescence/bring-me-to-life.htm',
#  '/songteksten/68458/evanescence/cartoon-network.htm',
#  '/songteksten/890454/evanescence/the-end-of-the-dream.htm',
#  '/songteksten/360153/evanescence/holding-my-last-breathe.htm',
#  '/songteksten/67515/evanescence/weight-of-the-world.htm',
#  '/songteksten/53025/evanescence/thoughless.htm',
#  '/songteksten/41307/evanescence/exodus--demo-.htm',
#  '/songteksten/53438/evanescence/feel-for-you.htm',
#  '/songteksten/795872/evanescence/disappear.htm',
#  '/songteksten/43244/evanescence/understanding.htm',
#  '/songteksten/360788/evanescence/my-heart-is-broken.htm',
#  '/songteksten/45472/evanescence/give-unto-me.htm',
#  '/songteksten/174661/evanescence/field-of-innocence.htm',
#  '/songteksten/174662/evanescence/eternal.htm',
#  '/songteksten/43024/evanescence/anywhere.htm',
#  '/songteksten/889460/evanescence/imperfection.htm',
#  '/songteksten/67732/evanescence/lacrymose.htm',
#  '/songteksten/360750/evanescence/made-of-stone-.htm',
#  '/songteksten/41318/evanescence/tourniquet.htm',
#  '/songteksten/74929/evanescence/the-last-song-i-m-wasting-on-you.htm',
#  '/songteksten/41306/evanescence/everybody-s-fool.htm',
#  '/songteksten/67511/evanescence/lose-control.htm',
#  '/songteksten/994425/evanescence/the-in-between--piano-solo-.htm',
#  '/songteksten/67509/evanescence/like-you.htm',
#  '/songteksten/890455/evanescence/hi-lo.htm',
#  '/songteksten/43245/evanescence/missing.htm',
#  '/songteksten/43907/evanescence/the-last-day.htm',
#  '/songteksten/360416/evanescence/what-you-want.htm',
#  '/songteksten/67504/evanescence/all-that-i-m-living-for.htm',
#  '/songteksten/56458/evanescence/wisper.htm',
#  '/songteksten/41320/evanescence/whisper.htm',
#  '/songteksten/66131/evanescence/my-tourniquet.htm',
#  '/songteksten/67508/evanescence/lacrymosa.htm',
#  '/songteksten/45786/evanescence/thoughtless.htm',
#  '/songteksten/360790/evanescence/the-change.htm',
#  '/songteksten/43025/evanescence/i-must-be-dreaming.htm',
#  '/songteksten/49240/evanescence/forever-gone-forever-you.htm',
#  '/songteksten/795424/evanescence/sick.htm',
#  '/songteksten/994419/evanescence/overture.htm',
#  '/songteksten/42850/evanescence/imaginary.htm',
#  '/songteksten/74926/evanescence/imaginery.htm',
#  '/songteksten/74927/evanescence/jealous.htm',
#  '/songteksten/45471/evanescence/so-close.htm',
#  '/songteksten/174664/evanescence/ascension-of-the-spirit.htm',
#  '/songteksten/41321/evanescence/you.htm',
#  '/songteksten/48712/evanescence/you--amy-lee-solo-.htm',
#  '/songteksten/795870/evanescence/on-the-songs%3a-lost-in-paradise.htm',
#  '/songteksten/45011/evanescence/broken.htm',
#  '/songteksten/41812/evanescence/even-in-death.htm',
#  '/songteksten/41315/evanescence/my-immortal.htm',
#  '/songteksten/45787/evanescence/zero.htm',
#  '/songteksten/795421/evanescence/swimming-home.htm',
#  '/songteksten/48711/evanescence/forever.htm',
#  '/songteksten/41317/evanescence/taking-over-me.htm',
#  '/songteksten/795422/evanescence/never-go-back.htm',
#  '/songteksten/360165/evanescence/sally-s-song.htm',
#  '/songteksten/49745/evanescence/heart-shaped-box.htm',
#  '/songteksten/48710/evanescence/exodus.htm',
#  '/songteksten/174659/evanescence/the-end.htm',
#  '/songteksten/362685/evanescence/erase-this.htm',
#  '/songteksten/891173/evanescence/bring-me-to-life--synthesis-.htm',
#  '/songteksten/41312/evanescence/hello.htm',
#  '/songteksten/42849/evanescence/lies.htm',
#  '/songteksten/41316/evanescence/my-last-breath.htm',
#  '/songteksten/67505/evanescence/call-me-when-you-re-sober.htm',
#  '/songteksten/45470/evanescence/listen-to-the-rain.htm']

# %% [markdown]
# A quick inspection reveals often misspelling.

# %% [markdown]
# ### Retrieving from [AZLyrics](https://www.azlyrics.com/)
#
# The last website investigated as the first one has only one main page with all lyrics.

# %%
url = 'https://www.azlyrics.com/e/evanescence.html'

list_links_lyrics_azlyrics = retrieve_hyperlinks(url)

# removing possible repetitions 

list_links_lyrics_azlyrics = list(set(list_links_lyrics_azlyrics))

print('\n Number of links before filtering:', len(list_links_lyrics_azlyrics))
list_links_lyrics_azlyrics
# Out:
#  Number of links before filtering: 128
# ['//www.azlyrics.com/copyright.html',
#  '../lyrics/evanescence/whisper.html',
#  '../lyrics/evanescence/haunteddemo.html',
#  '//www.stlyrics.com',
#  '//www.azlyrics.com/o.html',
#  '../lyrics/evanescence/snowwhitequeen.html',
#  '../lyrics/evanescence/wherewillyougo.html',
#  '../lyrics/evanescence/soclose.html',
#  '../lyrics/evanescence/whatyouwant.html',
#  '../lyrics/evanescence/takingoverme.html',
#  '../lyrics/evanescence/forgiveme.html',
#  '../lyrics/evanescence/goodnight.html',
#  '../lyrics/evanescence/ifyoudontmind.html',
#  '../lyrics/evanescence/breathenomore.html',
#  '../lyrics/evanescence/thechange.html',
#  '../lyrics/evanescence/hello.html',
#  '../a/amylee.html',
#  '../lyrics/evanescence/heartshapedbox.html',
#  '../lyrics/evanescence/losecontrol.html',
#  '../lyrics/evanescence/exodus.html',
#  '../lyrics/evanescence/october.html',
#  '../lyrics/evanescence/untitledyoucantkillthemeinyou.html',
#  '//www.azlyrics.com/z.html',
#  '../lyrics/evanescence/everybodysfool.html',
#  '//www.azlyrics.com',
#  '../lyrics/evanescence/lostwhispers.html',
#  '../lyrics/evanescence/hilo.html',
#  '../lyrics/evanescence/fartheraway.html',
#  '../lyrics/evanescence/thechain.html',
#  '//www.azlyrics.com/contact.html',
#  '../lyrics/evanescence/solitude.html',
#  '../lyrics/evanescence/haunted.html',
#  '../lyrics/evanescence/evenindeath.html',
#  '../lyrics/evanescence/thoughtless.html',
#  '../lyrics/evanescence/weightoftheworld.html',
#  '//www.azlyrics.com/r.html',
#  '../lyrics/evanescence/listentotherain.html',
#  '../lyrics/evanescence/imperfection.html',
#  '../lyrics/evanescence/theendofthedream.html',
#  '../lyrics/evanescence/cloudnine.html',
#  '//www.azlyrics.com/p.html',
#  '../lyrics/evanescence/goingunder.html',
#  '../lyrics/evanescence/surrender.html',
#  '../lyrics/evanescence/bringmetolifesynthesis.html',
#  '//www.azlyrics.com/privacy.html',
#  '../lyrics/evanescence/thelastsongimwastingonyou.html',
#  '../lyrics/evanescence/lacrymosa572218.html',
#  '../lyrics/evanescence/madeofstone.html',
#  '//www.azlyrics.com/s.html',
#  '//www.azlyrics.com/e.html',
#  '../lyrics/evanescence/erasethis.html',
#  '../lyrics/evanescence/nevergoback.html',
#  '../lyrics/evanescence/sayyouwill.html',
#  '//www.azlyrics.com/w.html',
#  '../lyrics/evanescence/sweetsacrifice.html',
#  '../lyrics/evanescence/takecover.html',
#  '//www.azlyrics.com/k.html',
#  '../lyrics/evanescence/secretdoor.html',
#  '../lyrics/evanescence/lithium.html',
#  'https://www.facebook.com/sharer.php?u=https%3A%2F%2Fwww.azlyrics.com%2Fe%2Fevanescence.html&title=Evanescence%20Lyrics&display=page',
#  '../lyrics/evanescence/lies.html',
#  '../lyrics/evanescence/lostinparadise.html',
#  '../lyrics/evanescence/beforethedawn.html',
#  '//www.azlyrics.com/q.html',
#  '//www.azlyrics.com/adv.html',
#  '../lyrics/evanescence/myimmortal.html',
#  '../lyrics/evanescence/awayfromme.html',
#  'mailto:?subject=Evanescence%20Lyrics&body=https%3A%2F%2Fwww.azlyrics.com%2Fe%2Fevanescence.html',
#  '//www.azlyrics.com/d.html',
#  '//www.azlyrics.com/u.html',
#  '//www.azlyrics.com/g.html',
#  '../lyrics/evanescence/tourniquet.html',
#  'https://twitter.com/intent/tweet?url=https%3A%2F%2Fwww.azlyrics.com%2Fe%2Fevanescence.html&text=Evanescence%20Lyrics',
#  '//www.azlyrics.com/c.html',
#  '//www.azlyrics.com/t.html',
#  '//www.azlyrics.com/b.html',
#  '//www.azlyrics.com/m.html',
#  '../lyrics/evanescence/disappear.html',
#  '//www.azlyrics.com/v.html',
#  '../lyrics/evanescence/imaginaryorigin.html',
#  '../lyrics/evanescence/you.html',
#  '//www.azlyrics.com/n.html',
#  '//www.azlyrics.com/f.html',
#  '../lyrics/evanescence/evenindeath2016version.html',
#  '../lyrics/evanescence/theonlyone.html',
#  '../lyrics/evanescence/itwasallalie.html',
#  '//www.azlyrics.com/y.html',
#  '../lyrics/evanescence/understandingwashitallaway.html',
#  '//www.azlyrics.com/l.html',
#  '../lyrics/evanescence/myheartisbroken572217.html',
#  '../lyrics/evanescence/whisperoriginversion.html',
#  '//www.azlyrics.com/j.html',
#  '../lyrics/evanescence/fieldofinnocence.html',
#  '../lyrics/evanescence/forevergoneforeveryou.html',
#  '../lyrics/evanescence/togetheragain.html',
#  '../lyrics/evanescence/mylastbreath.html',
#  '//www.azlyrics.com/19.html',
#  '../lyrics/evanescence/swimminghome.html',
#  '../lyrics/evanescence/zero.html',
#  '../add.php',
#  '//www.facebook.com/pages/AZLyricscom/154139197951223',
#  '//www.azlyrics.com/i.html',
#  '../lyrics/evanescence/goodenough.html',
#  '../lyrics/evanescence/bleedimustbedreaming.html',
#  '../lyrics/evanescence/origin.html',
#  '../lyrics/evanescence/allthatimlivingfor.html',
#  '//www.azlyrics.com/h.html',
#  '../lyrics/evanescence/giveuntome.html',
#  '../lyrics/evanescence/likeyou.html',
#  '../lyrics/evanescence/imaginary572221.html',
#  '../lyrics/evanescence/callmewhenyouresober.html',
#  '../lyrics/evanescence/imaginary.html',
#  '../lyrics/evanescence/sick.html',
#  '../lyrics/evanescence/endofthedream.html',
#  '../lyrics/evanescence/missing.html',
#  '../lyrics/evanescence/theotherside.html',
#  '../lyrics/evanescence/bringmetolife.html',
#  '../lyrics/evanescence/lacrymosa.html',
#  '../lyrics/evanescence/anewwaytobleed.html',
#  '//www.azlyrics.com/cookie.html',
#  '../lyrics/evanescence/myimmortal572226.html',
#  '//www.azlyrics.com/x.html',
#  '../lyrics/evanescence/anywhere.html',
#  '../lyrics/evanescence/anythingforyou.html',
#  '../lyrics/evanescence/myheartisbroken.html',
#  '../lyrics/evanescence/yourstar.html',
#  '//www.azlyrics.com/a.html',
#  '../lyrics/evanescence/oceans.html']

# %% [markdown]
# And in this case our filtering list comprehension uses '/lyrics/' to keep only the relevant links.

# %%
list_links_lyrics_azlyrics = [link for link in list_links_lyrics_azlyrics if '/lyrics/' in link ]

print('\n Number of links after updated filtering and applying set:', len(list_links_lyrics_azlyrics))
# Out:
#  Number of links after updated filtering and applying set: 88

# %%
# organizing in alphabetical order to make visualization easy
list_links_lyrics_azlyrics.sort()
list_links_lyrics_azlyrics
# Out:
# ['../lyrics/evanescence/allthatimlivingfor.html',
#  '../lyrics/evanescence/anewwaytobleed.html',
#  '../lyrics/evanescence/anythingforyou.html',
#  '../lyrics/evanescence/anywhere.html',
#  '../lyrics/evanescence/awayfromme.html',
#  '../lyrics/evanescence/beforethedawn.html',
#  '../lyrics/evanescence/bleedimustbedreaming.html',
#  '../lyrics/evanescence/breathenomore.html',
#  '../lyrics/evanescence/bringmetolife.html',
#  '../lyrics/evanescence/bringmetolifesynthesis.html',
#  '../lyrics/evanescence/callmewhenyouresober.html',
#  '../lyrics/evanescence/cloudnine.html',
#  '../lyrics/evanescence/disappear.html',
#  '../lyrics/evanescence/endofthedream.html',
#  '../lyrics/evanescence/erasethis.html',
#  '../lyrics/evanescence/evenindeath.html',
#  '../lyrics/evanescence/evenindeath2016version.html',
#  '../lyrics/evanescence/everybodysfool.html',
#  '../lyrics/evanescence/exodus.html',
#  '../lyrics/evanescence/fartheraway.html',
#  '../lyrics/evanescence/fieldofinnocence.html',
#  '../lyrics/evanescence/forevergoneforeveryou.html',
#  '../lyrics/evanescence/forgiveme.html',
#  '../lyrics/evanescence/giveuntome.html',
#  '../lyrics/evanescence/goingunder.html',
#  '../lyrics/evanescence/goodenough.html',
#  '../lyrics/evanescence/goodnight.html',
#  '../lyrics/evanescence/haunted.html',
#  '../lyrics/evanescence/haunteddemo.html',
#  '../lyrics/evanescence/heartshapedbox.html',
#  '../lyrics/evanescence/hello.html',
#  '../lyrics/evanescence/hilo.html',
#  '../lyrics/evanescence/ifyoudontmind.html',
#  '../lyrics/evanescence/imaginary.html',
#  '../lyrics/evanescence/imaginary572221.html',
#  '../lyrics/evanescence/imaginaryorigin.html',
#  '../lyrics/evanescence/imperfection.html',
#  '../lyrics/evanescence/itwasallalie.html',
#  '../lyrics/evanescence/lacrymosa.html',
#  '../lyrics/evanescence/lacrymosa572218.html',
#  '../lyrics/evanescence/lies.html',
#  '../lyrics/evanescence/likeyou.html',
#  '../lyrics/evanescence/listentotherain.html',
#  '../lyrics/evanescence/lithium.html',
#  '../lyrics/evanescence/losecontrol.html',
#  '../lyrics/evanescence/lostinparadise.html',
#  '../lyrics/evanescence/lostwhispers.html',
#  '../lyrics/evanescence/madeofstone.html',
#  '../lyrics/evanescence/missing.html',
#  '../lyrics/evanescence/myheartisbroken.html',
#  '../lyrics/evanescence/myheartisbroken572217.html',
#  '../lyrics/evanescence/myimmortal.html',
#  '../lyrics/evanescence/myimmortal572226.html',
#  '../lyrics/evanescence/mylastbreath.html',
#  '../lyrics/evanescence/nevergoback.html',
#  '../lyrics/evanescence/oceans.html',
#  '../lyrics/evanescence/october.html',
#  '../lyrics/evanescence/origin.html',
#  '../lyrics/evanescence/sayyouwill.html',
#  '../lyrics/evanescence/secretdoor.html',
#  '../lyrics/evanescence/sick.html',
#  '../lyrics/evanescence/snowwhitequeen.html',
#  '../lyrics/evanescence/soclose.html',
#  '../lyrics/evanescence/solitude.html',
#  '../lyrics/evanescence/surrender.html',
#  '../lyrics/evanescence/sweetsacrifice.html',
#  '../lyrics/evanescence/swimminghome.html',
#  '../lyrics/evanescence/takecover.html',
#  '../lyrics/evanescence/takingoverme.html',
#  '../lyrics/evanescence/thechain.html',
#  '../lyrics/evanescence/thechange.html',
#  '../lyrics/evanescence/theendofthedream.html',
#  '../lyrics/evanescence/thelastsongimwastingonyou.html',
#  '../lyrics/evanescence/theonlyone.html',
#  '../lyrics/evanescence/theotherside.html',
#  '../lyrics/evanescence/thoughtless.html',
#  '../lyrics/evanescence/togetheragain.html',
#  '../lyrics/evanescence/tourniquet.html',
#  '../lyrics/evanescence/understandingwashitallaway.html',
#  '../lyrics/evanescence/untitledyoucantkillthemeinyou.html',
#  '../lyrics/evanescence/weightoftheworld.html',
#  '../lyrics/evanescence/whatyouwant.html',
#  '../lyrics/evanescence/wherewillyougo.html',
#  '../lyrics/evanescence/whisper.html',
#  '../lyrics/evanescence/whisperoriginversion.html',
#  '../lyrics/evanescence/you.html',
#  '../lyrics/evanescence/yourstar.html',
#  '../lyrics/evanescence/zero.html']

# %% [markdown]
# # **Extract lyrics from a webpage**
#
# Now is time to use hyperlinks of the lyrics obtained in the previous section to extract lyrics.
#
# From the sites inspected before, I've decided to eliminate songteksten.nl because of the misspelling issues, and to work further with songteksten.net because it seemed to be the less complicate to extract lyrics.
#
# The following functions handle this task by using `BeautifullSoup` to parse the html and prettify it. After that I have used some strings methods from Python to have the lyrics both in string format but also in list format.

# %%
url_lyric = 'https://songteksten.net/lyric/1938/30609/evanescence/bring-me-to-life.html'
r_lyric = requests.get(url_lyric)

# %%
r_lyric
# Out:
# <Response [200]>

# %%
html_doc_lyric = r_lyric.text
html_doc_lyric
# Out:
# '<!DOCTYPE html>\n<html lang="nl">\n<head>\n<meta charset="iso-8859-1">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="viewport" content="width=device-width, initial-scale=1">\n<meta name="robots" content="index, follow" />\n<title>Songteksten.net - Songtekst: Evanescence - Bring Me To Life</title>\n<meta name="description" content="Bekijk de songtekst Bring Me To Life van Evanescence op Songteksten.net">\n<meta name="verify-v1" content="Z400kCtagpTtN7S0faT4/8v+PFXYrWHVMhCEOLMOQYk=" />\n<meta name="google-site-verification" content="uyniupsja-pMOHt0klVT2713XR6GflHhdoBeh5uqwgk" />\n<base href="https://songteksten.net/" />\n<link rel="stylesheet" href="/css/bootstrap.min.css" />\n<link rel="stylesheet" href="/css/template.min.css?201901" />\n<script src="/js/jquery-2.2.0.min.js"></script>\n<script src="/js/bootstrap.min.js"></script>\n<script async src="//edgecastcdn.net/000540/cdn/client/bandhosting/init.js" type="text/javascript"></script>\n<link rel="shortcut icon" href="/img/favicon.ico" type="image/x-icon" />\n<script src="/js/jquery.lyric.min.js?201901"></script>\n<link rel="stylesheet" type="text/css" href="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.css" />\n<script src="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.js"></script>\n<script>\n        window.addEventListener("load", function () {\n            window.cookieconsent.initialise({\n                "palette": {\n                    "popup": {\n                        "background": "#ebebeb",\n                        "text": "#666666"\n                    },\n                    "button": {\n                        "background": "#f16524",\n                        "text": "#ffffff"\n                    }\n                },\n                "theme": "classic",\n                "type": "opt-out",\n                "content": {\n                    "message": "Om Songteksten.net goed te laten functioneren maken we gebruik van cookies. ",\n                    "dismiss": "Akkoord!",\n                    "deny": "Weigeren",\n                    "link": "Meer informatie.",\n                    "href": "https://songteksten.net/info/1186/privacy.html"\n                }\n            })\n        });\n    </script>\n</head>\n<body>\n<div class="container">\n<div class="row">\n<div class="col-sm-12">\n<div class="pull-righ"><div id="WA_SONGTEKSTEN_BILLBOARD"></div></div>\n</div>\n</div>\n<div class="main-container">\n<nav class="navbar navbar-default"><div class="navbar-header"><button type="button" class="navbar-toggle collapsed" data-toggle="collapse" data-target="#navigation" aria-expanded="false"><span class="sr-only">Toggle navigation</span><span class="icon-bar"></span><span class="icon-bar"></span><span class="icon-bar"></span></button></div><div id="navigation" class="collapse navbar-collapse"><ul class="nav navbar-nav"><li><a href="//songteksten.net">Home</a></li><li class="dropdown active"><a href="#" class="dropdown-toggle" data-toggle="dropdown" role="button">Songteksten <span class="caret"></span></a><ul class="dropdown-menu"><li><a href="//songteksten.net/artists.html">Artiesten bekijken</a></li><li><a href="//songteksten.net/lyrics/latest.html">Nieuwste</a></li><li><a href="//songteksten.net/lyrics/popular.html">Populairste</a></li><li><a href="//songteksten.net/genres.html">Genres</a></li><li><a href="//songteksten.net/videos.html">Video\'s</a></li><li><a href="//songteksten.net/lyric/add.html">Toevoegen</a></li></ul></li><li class="dropdown"><a href="#" class="dropdown-toggle" data-toggle="dropdown" role="button">Albums <span class="caret"></span></a><ul class="dropdown-menu"><li><a href="//songteksten.net/albums.html">Nieuwste</a></li><li><a href="//songteksten.net/albums/add.html">Toevoegen</a></li></ul></li><li class="dropdown"><a href="#" class="dropdown-toggle" data-toggle="dropdown" role="button">Vertalingen <span class="caret"></span></a><ul class="dropdown-menu"><li><a href="// ...

# %%
soup_lyric = BeautifulSoup(html_doc_lyric,"lxml")
soup_lyric
# Out:
# <!DOCTYPE html>
# <html lang="nl">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="index, follow" name="robots"/>
# <title>Songteksten.net - Songtekst: Evanescence - Bring Me To Life</title>
# <meta content="Bekijk de songtekst Bring Me To Life van Evanescence op Songteksten.net" name="description"/>
# <meta content="Z400kCtagpTtN7S0faT4/8v+PFXYrWHVMhCEOLMOQYk=" name="verify-v1"/>
# <meta content="uyniupsja-pMOHt0klVT2713XR6GflHhdoBeh5uqwgk" name="google-site-verification"/>
# <base href="https://songteksten.net/"/>
# <link href="/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="/css/template.min.css?201901" rel="stylesheet"/>
# <script src="/js/jquery-2.2.0.min.js"></script>
# <script src="/js/bootstrap.min.js"></script>
# <script async="" src="//edgecastcdn.net/000540/cdn/client/bandhosting/init.js" type="text/javascript"></script>
# <link href="/img/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <script src="/js/jquery.lyric.min.js?201901"></script>
# <link href="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.css" rel="stylesheet" type="text/css"/>
# <script src="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.js"></script>
# <script>
#         window.addEventListener("load", function () {
#             window.cookieconsent.initialise({
#                 "palette": {
#                     "popup": {
#                         "background": "#ebebeb",
#                         "text": "#666666"
#                     },
#                     "button": {
#                         "background": "#f16524",
#                         "text": "#ffffff"
#                     }
#                 },
#                 "theme": "classic",
#                 "type": "opt-out",
#                 "content": {
#                     "message": "Om Songteksten.net goed te laten functioneren maken we gebruik van cookies. ",
#                     "dismiss": "Akkoord!",
#                     "deny": "Weigeren",
#                     "link": "Meer informatie.",
#                     "href": "https://songteksten.net/info/1186/privacy.html"
#                 }
#             })
#         });
#     </script>
# </head>
# <body>
# <div class="container">
# <div class="row">
# <div class="col-sm-12">
# <div class="pull-righ"><div id="WA_SONGTEKSTEN_BILLBOARD"></div></div>
# </div>
# </div>
# <div class="main-container">
# <nav class="navbar navbar-default"><div class="navbar-header"><button aria-expanded="false" class="navbar-toggle collapsed" data-target="#navigation" data-toggle="collapse" type="button"><span class="sr-only">Toggle navigation</span><span class="icon-bar"></span><span class="icon-bar"></span><span class="icon-bar"></span></button></div><div class="collapse navbar-collapse" id="navigation"><ul class="nav navbar-nav"><li><a href="//songteksten.net">Home</a></li><li class="dropdown active"><a class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">Songteksten <span class="caret"></span></a><ul class="dropdown-menu"><li><a href="//songteksten.net/artists.html">Artiesten bekijken</a></li><li><a href="//songteksten.net/lyrics/latest.html">Nieuwste</a></li><li><a href="//songteksten.net/lyrics/popular.html">Populairste</a></li><li><a href="//songteksten.net/genres.html">Genres</a></li><li><a href="//songteksten.net/videos.html">Video's</a></li><li><a href="//songteksten.net/lyric/add.html">Toevoegen</a></li></ul></li><li class="dropdown"><a class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">Albums <span class="caret"></span></a><ul class="dropdown-menu"><li><a href="//songteksten.net/albums.html">Nieuwste</a></li><li><a href="//songteksten.net/albums/add.html">Toevoegen</a></li></ul></li><li class="dropdown"><a class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">Vertalingen <span class="caret"></span></a><ul class="dropdown-menu"><li><a href="//songteksten.net/translations/latest.html">Nieuwste</a></li><li><a href="//songteksten.net/translations/popular.html">Populairste</a></li></ul></li><li><a href="//forum.songteksten.net">Community</a></li><li class="dropdown"><a class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">MijnSongteksten <span class="caret"></span></a><ul class="dropdown-menu"><li class="separator"><a href="//forum.songteksten.net/index.php?action=login">Inloggen</a></li></ul></li></ul><form action="/search.html" class="col-sm-3 pull-right hidden-xs hidden-sm form-search" method="get"><div class="input-group"><input class="form-control" name="q" placeholder="Zoeken..." type="text"/><input name="type[]" type="hidden" value="title"/><input name="type[]" type="hidden" value="artist"/><span class="input-group-btn"><button class="btn btn-default" type="submit">Go!</button></span></div></form></div></nav> <form action="/search.html" class="visible-xs form-search" method="get">
# <div class="input-group input-group-lg">
# <input class="form-control" name="q" placeholder="Zoeken..." type="text"/>
# <input name="type[]" type="hidden" value="title"/>
# <input name="type[]" type="hidden" value="artist"/>
# <span class="input-group-btn"><button class="btn btn-default" type="submit">Go!</button></span>
# </div>
# </form>
# <div class="header">
# <a href="/"><img alt="logo songteksten.net" class="logo" src="/img/logo.png"/></a>
# </div>
# <div class="btn-group btn-group-letters">
# <a class="btn btn-default" href="https://songteksten.net/artists/1.html" title="Bekijk alle artiesten van de letter 1">1</a><a class="btn btn-default" href="https://songteksten.net/artists/2.html" title="Bekijk alle artiesten van de letter 2">2</a><a class="btn btn-default" href="https://songteksten.net/artists/3.html" title="Bekijk alle artiesten van de letter 3">3</a><a class="btn btn-default" href="https://songteksten.net/artists/4.html" title="Bekijk alle artiesten van de letter 4">4</a><a class="btn btn-default" href="https://songteksten.net/artists/5.html" title="Bekijk alle artiesten van de letter 5">5</a><a class="btn btn-default" href="https://songteksten.net/artists/6.html" title="Bekijk alle artiesten van de letter 6">6</a><a class="btn btn-default" href="https://songteksten.net/artists/7.html" title="Bekijk alle artiesten van de letter 7">7</a><a class="btn btn-default" href="https://songteksten.net/artists/8.html" title="Bekijk alle artiesten van de letter 8">8</a><a class="btn btn-default" href="https://songteksten.net/artists/9.html" title="Bekijk alle artiesten van de letter 9">9</a><a class="btn btn-default" href="https://songteksten.net/artists/a.html" title="Bekijk alle artiesten van de letter a">A</a><a class="btn btn-default" href="https://songteksten.net/artists/b.html" title="Bekijk alle artiesten van de letter b">B</a><a class="btn btn-default" href="https://songteksten.net/artists/c.html" title="Bekijk alle artiesten van de letter c">C</a><a class="btn btn-default" href="https://songteksten.net/artists/d.html" title="Bekijk alle artiesten van de letter d">D</a><a class="btn btn-default" href="https://songteksten.net/artists/e.html" title="Bekijk alle artiesten van de letter e">E</a><a class="btn btn-default" href="https://songteksten.net/artists/f.html" title="Bekijk alle artiesten van de letter f">F</a><a class="btn btn-default" href="https://songteksten.net/artists/g.html" title="Bekijk alle artiesten van de letter g">G</a><a class="btn btn-default" href="https://songteksten.net/artists/h.html" title="Bekijk alle artiesten van de letter h">H</a><a class="btn btn-default" href="https://songteksten.net/artists/i.html" title="Bekijk alle artiesten van de letter i">I</a><a class="btn btn-default" href="https://songteksten.net/artists/j.html" title="Bekijk alle artiesten van de letter j">J</a><a class="btn btn-default" href="https://songteksten.net/artists/k.html" title="Bekijk alle artiesten van de letter k">K</a><a class="btn btn-default" href="https://songteksten.net/artists/l.html" title="Bekijk alle artiesten van de letter l">L</a><a class="btn btn-default" href="https://songteksten.net/artists/m.html" title="Bekijk alle artiesten van de letter m">M</a><a class="btn btn-default" href="https://songteksten.net/artists/n.html" title="Bekijk alle artiesten van de letter n">N</a><a class="btn btn-default" href="https://songteksten.net/artists/o.html" title="Bekijk alle artiesten van de letter o">O</a><a class="btn btn-default" href="https://songteksten.net/artists/p.html" title="Bekijk alle artiesten van de letter p">P</a><a class="btn btn-default" href="https://songteksten.net/artists/q.html" title="Bekijk alle artiesten van de letter q">Q</a><a class="btn btn-default" href="https://songteksten.net/artists/r.html" title="Bekijk alle artiesten van de letter r">R</a><a class="btn btn-default" href="https://songteksten.net/artists/s.html" title="Bekijk alle artiesten van de letter s">S</a><a class="btn btn-default" href="https://songteksten.net/artists/t.html" title="Bekijk alle artiesten van de letter t">T</a><a class="btn btn-default" href="https://songteksten.net/artists/u.html" title="Bekijk alle artiesten van de letter u">U</a><a class="btn btn-default" href="https://songteksten.net/artists/v.html" title="Bekijk alle artiesten van de letter v">V</a><a class="btn btn-default" href="https://songteksten.net/artists/w.html" title="Bekijk alle artiesten van de letter w">W</a><a class="btn btn-default" href= ...
# <div class="row">
# <div class="breadcrumb-container col-sm-12">
# <div class="login-box hidden-xs hidden-sm pull-right col-md-5 col-lg-4">
# <div class="col-sm-12"><form action="https://forum.songteksten.net?action=login2" class="form-inline form-forum-login pull-right" method="post"><div class="form-group"><input class="form-control input-sm" id="user" name="user" placeholder="Gebruikersnaam" size="18" type="text" value=""/></div> <div class="form-group"><input class="form-control input-sm" id="passwrd" name="passwrd" placeholder="Wachtwoord" size="18" type="password"/></div> <div class="form-group"><button class="btn btn-primary btn-sm" type="submit">Inloggen</button></div></form></div>
# </div>
# <ol class="breadcrumb">
# <li><a href="https://songteksten.net/">Home</a></li><li><a href="https://songteksten.net/artists/e.html">e</a></li><li><a href="https://songteksten.net/artist/lyrics/1938/evanescence.html">Evanescence</a></li><li><a href="https://songteksten.net/artist/lyrics/1938/evanescence.html">Songteksten</a></li><li>Bring Me To Life</li> </ol>
# </div>
# </div>
# <div class="flex">
# <div class="col-sm-12">
# <div class="row">
# <div class="col-sm-3 flex-left hidden-xs"> <div class="module hidden-xs">
# <h3>Laatste nieuws</h3>
# <ul class="list-unstyled">
# <li><small class="text-muted">16:42 </small><a href="https://songteksten.net/news/102232/nederlandse-scenarist-wint-amerikaanse-filmprijs.html" title="Nederlandse scenarist wint Amerikaanse filmprijs  (0 reacties)">Nederlandse scenarist wint Amerikaanse filmprijs (0 reacties)</a></li><li><small class="text-muted">16:28 </small><a href="https://songteksten.net/news/102230/broer-aanslagpleger-concert-ariana-grande-net-zo-schuldig.html" title="'Broer aanslagpleger concert Ariana Grande net zo schuldig' (0 reacties)">'Broer aanslagpleger concert Ariana Grande net zo schuldig' (0 reacties)</a></li><li><small class="text-muted">16:26 </small><a href="https://songteksten.net/news/102231/grote-slijmfilm-met-bibi-en-djamila-breekt-records.html" title="Grote Slijmfilm met Bibi en Djamila breekt records (0 reacties)">Grote Slijmfilm met Bibi en Djamila breekt records (0 reacties)</a></li><li><small class="text-muted">15:55 </small><a href="https://songteksten.net/news/102229/anneke-van-giersbergen-nog-steeds-welkom-in-kerk-in-zwolle.html" title="Anneke van Giersbergen nog steeds welkom in kerk in Zwolle (0 reacties)">Anneke van Giersbergen nog steeds welkom in kerk in Zwolle (0 reacties)</a></li><li><small class="text-muted">15:01 </small><a href="https://songteksten.net/news/102228/beach-boys-frontman-roept-op-tot-boycot-beach-boys-concert.html" title="'Beach Boys-frontman' roept op tot boycot Beach Boys-concert (0 reacties)">'Beach Boys-frontman' roept op tot boycot Beach Boys-concert (0 reacties)</a></li><li><small class="text-muted">14:49 </small><a href="https://songteksten.net/news/102227/shannen-doherty-weer-gediagnosticeerd-met-kanker.html" title="Shannen Doherty weer gediagnosticeerd met kanker (0 reacties)">Shannen Doherty weer gediagnosticeerd met kanker (0 reacties)</a></li><li><small class="text-muted">14:38 </small><a href="https://songteksten.net/news/102226/organisatie-we-are-electric-slaat-jaar-over.html" title="Organisatie We Are Electric slaat jaar over (0 reacties)">Organisatie We Are Electric slaat jaar over (0 reacties)</a></li><li><small class="text-muted">13:47 </small><a href="https://songteksten.net/news/102225/marcel-van-roosmalen-verkozen-tot-republikein-van-het-jaar.html" title="Marcel van Roosmalen verkozen tot Republikein van het Jaar (0 reacties)">Marcel van Roosmalen verkozen tot Republikein van het Jaar (0 reacties)</a></li><li><small class="text-muted">13:37 </small><a href="https://songteksten.net/news/102224/veel-annuleringen-bij-meilandjes-na-verhuisbericht.html" title="Veel annuleringen bij Meilandjes na verhuisbericht (0 reacties)">Veel annuleringen bij Meilandjes na verhuisbericht (0 reacties)</a></li><li><small class="text-muted">13:05 </small><a href="https://songteksten.net/news/102223/madonna-biedt-harry-en-meghan-appartement-aan.html" title="Madonna biedt Harry en Meghan appartement aan (0 reacties)">Madonna biedt Harry en Meghan appartement aan (0 reacties)</a></li> </ul>
# </div>
# <div class="module">
# <h3>Populairste songteksten</h3>
# <ul class="list-unstyled">
# <li><small class="text-muted">40756 </small><a href="https://songteksten.net/lyric/8601/102664/maan/ze-huilt-maar-ze-lacht.html" title="Ze Huilt Maar Ze Lacht">Ze Huilt Maar Ze Lacht</a> - <a href="https://songteksten.net/artist/lyrics/8601/maan.html" title="Maan">Maan</a></li><li><small class="text-muted">10377 </small><a href="https://songteksten.net/lyric/9049/101801/danny-vera/roller-coaster.html" title="Roller Coaster">Roller Coaster</a> - <a href="https://songteksten.net/artist/lyrics/9049/danny-vera.html" title="Danny Vera">Danny Vera</a></li><li><small class="text-muted">9976 </small><a href="https://songteksten.net/lyric/9019/102741/snelle/smoorverliefd.html" title="Smoorverliefd">Smoorverliefd</a> - <a href="https://songteksten.net/artist/lyrics/9019/snelle.html" title="Snelle">Snelle</a></li><li><small class="text-muted">6459 </small><a href="https://songteksten.net/lyric/9064/102577/rolf-sanchez/pa-olvidarte.html" title="Pa Olvidarte">Pa Olvidarte</a> - <a href="https://songteksten.net/artist/lyrics/9064/rolf-sanchez.html" title="Rolf Sanchez">Rolf Sanchez</a>, <a href="https://songteksten.net/artist/lyrics/9217/emma-heesters.html" title="Emma Heesters">Emma Heesters</a></li><li><small class="text-muted">6181 </small><a href="https://songteksten.net/lyric/9019/102217/snelle/reunie.html" title="Reünie">Reünie</a> - <a href="https://songteksten.net/artist/lyrics/9019/snelle.html" title="Snelle">Snelle</a></li><li><small class="text-muted">5733 </small><a href="https://songteksten.net/lyric/60/98333/marco-borsato/mooi.html" title="Mooi">Mooi</a> - <a href="https://songteksten.net/artist/lyrics/60/marco-borsato.html" title="Marco Borsato">Marco Borsato</a></li><li><small class="text-muted">5112 </small><a href="https://songteksten.net/lyric/2881/102433/maroon-5/memories.html" title="Memories">Memories</a> - <a href="https://songteksten.net/artist/lyrics/2881/maroon-5.html" title="Maroon 5">Maroon 5</a></li><li><small class="text-muted">5085 </small><a href="https://songteksten.net/lyric/9173/102289/tones-and-i/dance-monkey.html" title="Dance Monkey">Dance Monkey</a> - <a href="https://songteksten.net/artist/lyrics/9173/tones-and-i.html" title="Tones And I">Tones And I</a></li><li><small class="text-muted">4373 </small><a href="https://songteksten.net/lyric/60/96869/marco-borsato/samen-voor-altijd.html" title="Samen Voor Altijd">Samen Voor Altijd</a> - <a href="https://songteksten.net/artist/lyrics/60/marco-borsato.html" title="Marco Borsato">Marco Borsato</a></li><li><small class="text-muted">3294 </small><a href="https://songteksten.net/lyric/2047/31578/nena/99-luftballons.html" title="99 Luftballons">99 Luftballons</a> - <a href="https://songteksten.net/artist/lyrics/2047/nena.html" title="Nena">Nena</a></li> </ul>
# </div>
# <div class="module hidden-xs">
# <h3>Nieuwste songteksten</h3>
# <ul class="list-unstyled">
# <li><small class="text-muted">11:06 </small><a href="https://songteksten.net/lyric/9247/102765/niks-aan-de-zeis/met-de-trekker-naar-s-gravenhage.html" title="Met de trekker naar 's-Gravenhage">Met de trekker naar 's-Gravenhage</a> - <a href="https://songteksten.net/artist/lyrics/9247/niks-aan-de-zeis.html" title="Niks aan de Zeis">Niks aan de Zeis</a></li><li><small class="text-muted">02-02 </small><a href="https://songteksten.net/lyric/3051/102764/samson-en-gert/samson-marie.html" title="Samson &amp; Marie">Samson &amp; Marie</a> - <a href="https://songteksten.net/artist/lyrics/3051/samson-en-gert.html" title="Samson En Gert">Samson En Gert</a></li><li><small class="text-muted">28-01 </small><a href="https://songteksten.net/lyric/5943/102763/demi-lovato/anyone.html" title="Anyone">Anyone</a> - <a href="https://songteksten.net/artist/lyrics/5943/demi-lovato.html" title="Demi Lovato">Demi Lovato</a></li><li><small class="text-muted">27-01 </small><a href="https://songteksten.net/lyric/8962/102762/merol/slippertje.html" title="Slippertje">Slippertje</a> - <a href="https://songteksten.net/artist/lyrics/8962/merol.html" title="MEROL">MEROL</a></li><li><small class="text-muted">25-01 </small><a href="https://songteksten.net/lyric/7419/102761/niels-destadsbader/hoofd-op-mijn-schouder.html" title="Hoofd Op Mijn Schouder">Hoofd Op Mijn Schouder</a> - <a href="https://songteksten.net/artist/lyrics/7419/niels-destadsbader.html" title="Niels Destadsbader">Niels Destadsbader</a></li><li><small class="text-muted">21-01 </small><a href="https://songteksten.net/lyric/545/102760/frans-bauer/geen-centen-maar-spullen.html" title="Geen Centen Maar Spullen">Geen Centen Maar Spullen</a> - <a href="https://songteksten.net/artist/lyrics/545/frans-bauer.html" title="Frans Bauer">Frans Bauer</a>, <a href="https://songteksten.net/artist/lyrics/9245/donnie.html" title="Donnie">Donnie</a></li><li><small class="text-muted">21-01 </small><a href="https://songteksten.net/lyric/9173/102759/tones-and-i/never-seen-the-rain.html" title="Never Seen The Rain">Never Seen The Rain</a> - <a href="https://songteksten.net/artist/lyrics/9173/tones-and-i.html" title="Tones And I">Tones And I</a></li><li><small class="text-muted">20-01 </small><a href="https://songteksten.net/lyric/8957/102758/billie-eilish/xanny.html" title="xanny">xanny</a> - <a href="https://songteksten.net/artist/lyrics/8957/billie-eilish.html" title="Billie Eilish">Billie Eilish</a></li><li><small class="text-muted">20-01 </small><a href="https://songteksten.net/lyric/8941/102757/future/mask-off.html" title="Mask Off">Mask Off</a> - <a href="https://songteksten.net/artist/lyrics/8941/future.html" title="Future">Future</a></li><li><small class="text-muted">20-01 </small><a href="https://songteksten.net/lyric/2543/102756/drake/life-is-good.html" title="Life Is Good">Life Is Good</a> - <a href="https://songteksten.net/artist/lyrics/2543/drake.html" title="Drake">Drake</a>, <a href="https://songteksten.net/artist/lyrics/8941/future.html" title="Future">Future</a></li> </ul>
# </div>
# <div class="module hidden-xs">
# <h3>Nieuwste albums</h3>
# <ul class="list-unstyled">
# <li><small class="date">25-01 </small><a href="https://songteksten.net/albums/album/7419/2310/niels-destadsbader/boven-de-wolken-fan-editie.html" title="Boven De wolken Fan-Editie 14-02-2020">Boven De wolken Fan-Editie</a> - <a href="https://songteksten.net/artist/lyrics/7419/niels-destadsbader.html" title="Niels Destadsbader">Niels Destadsbader</a></li><li><small class="date">02-01 </small><a href="https://songteksten.net/albums/album/7419/2308/niels-destadsbader/boven-de-wolken.html" title="Boven De Wolken 18-10-2019">Boven De Wolken</a> - <a href="https://songteksten.net/artist/lyrics/7419/niels-destadsbader.html" title="Niels Destadsbader">Niels Destadsbader</a></li><li><small class="date">02-01 </small><a href="https://songteksten.net/albums/album/7419/2307/niels-destadsbader/dertig.html" title="Dertig 30-05-2018">Dertig</a> - <a href="https://songteksten.net/artist/lyrics/7419/niels-destadsbader.html" title="Niels Destadsbader">Niels Destadsbader</a></li><li><small class="date">02-01 </small><a href="https://songteksten.net/albums/album/7419/2306/niels-destadsbader/speeltijd-niels-wiels-editie.html" title="Speeltijd Niels &amp; Wiels editie 17-02-2017">Speeltijd Niels &amp; Wiels editie</a> - <a href="https://songteksten.net/artist/lyrics/7419/niels-destadsbader.html" title="Niels Destadsbader">Niels Destadsbader</a></li><li><small class="date">02-01 </small><a href="https://songteksten.net/albums/album/7419/2305/niels-destadsbader/speeltijd.html" title="Speeltijd 21-10-2016">Speeltijd</a> - <a href="https://songteksten.net/artist/lyrics/7419/niels-destadsbader.html" title="Niels Destadsbader">Niels Destadsbader</a></li><li><small class="date">12-12 </small><a href="https://songteksten.net/albums/album/7902/2304/kensington/time.html" title="Time 15-11-2019">Time</a> - <a href="https://songteksten.net/artist/lyrics/7902/kensington.html" title="Kensington">Kensington</a></li><li><small class="date">24-10 </small><a href="https://songteksten.net/albums/album/7846/2302/tim-akkerman/lions-dont-cry.html" title="Lions Don't Cry 30-11--0001">Lions Don't Cry</a> - <a href="https://songteksten.net/artist/lyrics/7846/tim-akkerman.html" title="Tim Akkerman">Tim Akkerman</a></li><li><small class="date">15-07 </small><a href="https://songteksten.net/albums/album/8117/2300/ed-sheeran/no-6-collaborations-project.html" title="No. 6 Collaborations Project 12-07-2019">No. 6 Collaborations Project</a> - <a href="https://songteksten.net/artist/lyrics/8117/ed-sheeran.html" title="Ed Sheeran">Ed Sheeran</a></li><li><small class="date">08-07 </small><a href="https://songteksten.net/albums/album/232/2299/rammstein/rammstein.html" title="Rammstein 30-11--0001">Rammstein</a> - <a href="https://songteksten.net/artist/lyrics/232/rammstein.html" title="Rammstein">Rammstein</a></li><li><small class="date">05-07 </small><a href="https://songteksten.net/albums/album/4166/2298/earth-wind-and-fire/i-am.html" title="I Am 30-11--0001">I Am</a> - <a href="https://songteksten.net/artist/lyrics/4166/earth-wind-and-fire.html" title="Earth Wind And Fire">Earth Wind And Fire</a></li> </ul>
# </div>
# <div class="module hidden-xs">
# <h3>Laatste forumposts</h3>
# <ul class="list-unstyled forum">
# <li><span class="text-muted">18-12 </span><a href="https://forum.songteksten.net/index.php?topic=1327.msg86865;topicseen#new" target="_blank" title="Re: Hoe maak ik een nieuwe artiest aan?">Re: Hoe maak ik een nieuwe artiest aan?</a></li><li><span class="text-muted">08-11 </span><a href="https://forum.songteksten.net/index.php?topic=1327.msg86864;topicseen#new" target="_blank" title="Re: Hoe maak ik een nieuwe artiest aan?">Re: Hoe maak ik een nieuwe artiest aan?</a></li><li><span class="text-muted">11-10 </span><a href="https://forum.songteksten.net/index.php?topic=3543.msg86862;topicseen#new" target="_blank" title="Re: Tante Leen">Re: Tante Leen</a></li><li><span class="text-muted">11-10 </span><a href="https://forum.songteksten.net/index.php?topic=1327.msg86861;topicseen#new" target="_blank" title="Re: Hoe maak ik een nieuwe artiest aan?">Re: Hoe maak ik een nieuwe artiest aan?</a></li><li><span class="text-muted">09-10 </span><a href="https://forum.songteksten.net/index.php?topic=1327.msg86860;topicseen#new" target="_blank" title="Re: Hoe maak ik een nieuwe artiest aan?">Re: Hoe maak ik een nieuwe artiest aan?</a></li> </ul>
# </div>
# </div>
# <div class="col-sm-9 flex-right">
# <div class="row">
# <div class="col-sm-7 content-left"><h1>Evanescence - Bring Me To Life</h1>
# how can you see into my eyes<br/>
# like open doors<br/>
# leading you down into my core<br/>
# where I've become so numb without a soul<br/>
# my spirit sleeping somewhere cold<br/>
# until you find it there and lead it back home<br/>
# <br/>
# (Wake me up)<br/>
# Wake me up inside<br/>
# (I can't wake up)<br/>
# Wake me up inside<br/>
# (Save me)<br/>
# call my name and save me from the dark<br/>
# (Wake me up)<br/>
# bid my blood to run<br/>
# (I can't wake up)<br/>
# before I come undone<br/>
# (Save me)<br/>
# save me from the nothing I've become<br/>
# <br/>
# now that I know what I'm without<br/>
# you can't just leave me<br/>
# breathe into me and make me real<br/>
# bring me to life<br/>
# <br/>
# (Wake me up)<br/>
# Wake me up inside<br/>
# (I can't wake up)<br/>
# Wake me up inside<br/>
# (Save me)<br/>
# call my name and save me from the dark<br/>
# (Wake me up)<br/>
# bid my blood to run<br/>
# (I can't wake up)<br/>
# before I come undone<br/>
# (Save me)<br/>
# save me from the nothing I've become<br/>
# <br/>
# Bring me to life<br/>
# (I've been living a lie, there's nothing inside)<br/>
# Bring me to life<br/>
# <br/>
# frozen inside without your touch<br/>
# without your love darling<br/>
# only you are the life among the dead<br/>
# <br/>
# all this time I can't believe I couldn't see<br/>
# kept in the dark<br/>
# but you were there in front of me<br/>
# I've been sleeping a thousand years it seems<br/>
# got to open my eyes to everything<br/>
# without a thought without a voice without a soul<br/>
# don't let me die here<br/>
# there must be something more<br/>
# bring me to life<br/>
# <br/>
# (Wake me up)<br/>
# Wake me up inside<br/>
# (I can't wake up)<br/>
# Wake me up inside<br/>
# (Save me)<br/>
# call my name and save me from the dark<br/>
# (Wake me up)<br/>
# bid my blood to run<br/>
# (I can't wake up)<br/>
# before I come undone<br/>
# (Save me)<br/>
# save me from the nothing I've become<br/>
# <br/>
# (Bring me to life)<br/>
# I've been living a lie, there's nothing inside<br/>
# (Bring me to life)<div class="buma-consent" role="alert"><img align="left" alt="FEMU logo" class="img-responsive" src="/img/logo-femu.png"/> Songteksten.net heeft toestemming van Stichting FEMU om deze songtekst te tonen. De songteksten mogen niet anders dan voor prive-gebruik gebruikt worden, iedere andere verspreiding van de songteksten is niet toegestaan.</div></div>
# <div class="col-sm-5 content-right"><div id="WA_SONGTEKSTEN_HPA_TOP"></div><ul class="list-unstyled">
# <li><a href="https://songteksten.net/translation/1938/30609/evanescence/bring-me-to-life.html"><span class="glyphicon glyphicon-text-width"></span> Vertaling</a></li></ul>
# <h3>Artiesten</h3>
# <ul class="list-unstyled">
# <li><span class="glyphicon glyphicon-star"></span> <a href="https://songteksten.net/artist/lyrics/1938/evanescence.html">Evanescence</a></li></ul>
# <h3>Statistieken</h3>
# <ul class="list-unstyled">
# <li><span class="glyphicon glyphicon-star"></span> Bekeken: 131</li>
# <li><span class="glyphicon glyphicon-star"></span> Toegevoegd
# op: onbekend </li>
# <li><span class="glyphicon glyphicon-star"></span> Toegevoegd
# door: onbekend </li>
# <li><span class="glyphicon glyphicon-star"></span> Laatst gewijzigd
# op: onbekend </li>
# </ul>
# <h3>Toevoegen</h3>
# <ul class="list-unstyled">
# <li><a href="https://songteksten.net/lyric/add/1938.html"><span class="glyphicon glyphicon-plus"></span>
# Tekst toevoegen</a></li>
# </ul>
# <h3>Albums</h3>
# <ul class="list-unstyled">
# <li><a href="https://songteksten.net/albums/album/1938/344/evanescence/anywhere-but-home.html"><span class="glyphicon glyphicon-cd"></span> Anywhere But Home (22-11-2004)</a></li><li><a href="https://songteksten.net/albums/album/1938/171/evanescence/fallen.html"><span class="glyphicon glyphicon-cd"></span> Fallen (26-01-2004)</a></li> </ul>
# </div>
# </div>
# <div class="row">
# <div class="col-sm-12"><br/></div>
# </div>
# </div>
# </div>
# </div>
# <div class="col-sm-12">
# <div data-display="plista_widget_outstream"></div>
# <script type="text/javascript">
#                     (function(c){var g,s,n='script',w=window;w.PLISTA_=w.PLISTA_||[];w.PLISTA_.push(c);if(w.PLISTA_.length>1){return;}g=w.document.getElementsByTagName(n)[0];s=w.document.createElement(n);s.async=true;s.type='text/javascript';s.src=(w.location.protocol==='https:'?'https:':'http:')+'//static'+(c.origin?'-'+c.origin:'')+'.plista.com/async/min.js';g.parentNode.insertBefore(s,g);
#                     }({
#                         "publickey": "c89b4b0dedba7d7e7769023f",
#                         "origin": "nl",
#                         "dataMode": "data-display",
#                         "noCache": true,
#                         "widgets": [
#                             {
#                                 "name": "outstream",
#                                 "pub": {
#                                     "click": "%%CLICK_URL_UNESC%%",
#                                     "impression": "%%VIEW_URL_UNESC%%"
#                                 }
#                             }
#                         ],
#                         "sandbox": %%PREVIEW_MODE%%
#                     }));
#                 </script>
# </div>
# </div>
# <footer class="text-center">
# <a href="https://songteksten.net/adverteren.html">Adverteren</a> | <a href="https://songteksten.net/info/1185/over-ons.html">Over ons</a> | <a href="https://songteksten.net/info/1186/privacy.html">Je privacy</a> | <a href="https://songteksten.net/info/1187/rss-api-functies.html">RSS</a> </footer>
# </div>
# <p class="text-copyright text-center">© 2020 - Songteksten.net - Alle rechten voorbehouden.
# - Realisatie: <a href="http://bandhosting.nl" target="_blank">bandhosting.nl</a></p>
# </div>
# <script type="text/javascript">
#     var gaJsHost = (("https:" == document.location.protocol) ? "https://ssl." : "http://www.");
#     document.write(unescape("%3Cscript src='" + gaJsHost + "google-analytics.com/ga.js' type='text/javascript'%3E%3C/script%3E"));
# </script>
# <script type="text/javascript">
#     try {
#         var musicopy = _gat._getTracker("UA-68590-1");
#         musicopy._trackPageview();
#     } catch (err) {
#     }</script>
# <iframe frameborder="no" height="0" src="//images.webads.nl/stir/responsesongteksten_stir.htm" width="0"></iframe>
# <script>
#     (function (i, s, o, g, r, a, m) {
#         i['GoogleAnalyticsObject'] = r;
#         i[r] = i[r] || function () {
#             (i[r].q = i[r].q || []).push(arguments)
#         }, i[r].l = 1 * new Date();
#         a = s.createElement(o),
#             m = s.getElementsByTagName(o)[0];
#         a.async = 1;
#         a.src = g;
#         m.parentNode.insertBefore(a, m)
#     })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#     ga('set', 'anonymizeIp', true);
#     ga('create', 'UA-68590-10', 'auto');
#     ga('send', 'pageview');
# </script>
# </body>
# </html>

# %%
soup_lyric_pretty = soup_lyric.prettify()
print(soup_lyric_pretty)
# Out:
# <!DOCTYPE html>
# <html lang="nl">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="index, follow" name="robots"/>
#   <title>
#    Songteksten.net - Songtekst: Evanescence - Bring Me To Life
#   </title>
#   <meta content="Bekijk de songtekst Bring Me To Life van Evanescence op Songteksten.net" name="description"/>
#   <meta content="Z400kCtagpTtN7S0faT4/8v+PFXYrWHVMhCEOLMOQYk=" name="verify-v1"/>
#   <meta content="uyniupsja-pMOHt0klVT2713XR6GflHhdoBeh5uqwgk" name="google-site-verification"/>
#   <base href="https://songteksten.net/"/>
#   <link href="/css/bootstrap.min.css" rel="stylesheet"/>
#   <link href="/css/template.min.css?201901" rel="stylesheet"/>
#   <script src="/js/jquery-2.2.0.min.js">
#   </script>
#   <script src="/js/bootstrap.min.js">
#   </script>
#   <script async="" src="//edgecastcdn.net/000540/cdn/client/bandhosting/init.js" type="text/javascript">
#   </script>
#   <link href="/img/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
#   <script src="/js/jquery.lyric.min.js?201901">
#   </script>
#   <link href="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.css" rel="stylesheet" type="text/css"/>
#   <script src="//cdnjs.cloudflare.com/ajax/libs/cookieconsent2/3.0.3/cookieconsent.min.js">
#   </script>
#   <script>
#    window.addEventListener("load", function () {
#             window.cookieconsent.initialise({
#                 "palette": {
#                     "popup": {
#                         "background": "#ebebeb",
#                         "text": "#666666"
#                     },
#                     "button": {
#                         "background": "#f16524",
#                         "text": "#ffffff"
#                     }
#                 },
#                 "theme": "classic",
#                 "type": "opt-out",
#                 "content": {
#                     "message": "Om Songteksten.net goed te laten functioneren maken we gebruik van cookies. ",
#                     "dismiss": "Akkoord!",
#                     "deny": "Weigeren",
#                     "link": "Meer informatie.",
#                     "href": "https://songteksten.net/info/1186/privacy.html"
#                 }
#             })
#         });
#   </script>
#  </head>
#  <body>
#   <div class="container">
#    <div class="row">
#     <div class="col-sm-12">
#      <div class="pull-righ">
#       <div id="WA_SONGTEKSTEN_BILLBOARD">
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="main-container">
#     <nav class="navbar navbar-default">
#      <div class="navbar-header">
#       <button aria-expanded="false" class="navbar-toggle collapsed" data-target="#navigation" data-toggle="collapse" type="button">
#        <span class="sr-only">
#         Toggle navigation
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#        <span class="icon-bar">
#        </span>
#       </button>
#      </div>
#      <div class="collapse navbar-collapse" id="navigation">
#       <ul class="nav navbar-nav">
#        <li>
#         <a href="//songteksten.net">
#          Home
#         </a>
#        </li>
#        <li class="dropdown active">
#         <a class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">
#          Songteksten
#          <span class="caret">
#          </span>
#         </a>
#         <ul class="dropdown-menu">
#          <li>
#           <a href="//songteksten.net/artists.html">
#            Artiesten bekijken
#           </a>
#          </li>
#          <li>
#           <a href="//songteksten.net/lyrics/latest.html">
#            Nieuwste
#           </a>
#          </li>
#          <li>
#           <a href="//songteksten.net/lyrics/popular.html">
#            Populairste
#           </a>
#          </li>
#          <li>
#           <a href="//songteksten.net/genres.html">
#            Genres
#           </a>
#          </li>
#          <li>
#           <a href="//songteksten.net/videos.html">
#            Video's
#           </a>
#          </li>
#          <li>
#           <a href="//songteksten.net/lyric/add.html">
#            Toevoegen
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="dropdown">
#         <a class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">
#          Albums
#          <span class="caret">
#          </span>
#         </a>
#         <ul class="dropdown-menu">
#          <li>
#           <a href="//songteksten.net/albums.html">
#            Nieuwste
#           </a>
#          </li>
#          <li>
#           <a href="//songteksten.net/albums/add.html">
#            Toevoegen
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="dropdown">
#         <a class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">
#          Vertalingen
#          <span class="caret">
#          </span>
#         </a>
#         <ul class="dropdown-menu">
#          <li>
#           <a href="//songteksten.net/translations/latest.html">
#            Nieuwste
#           </a>
#          </li>
#          <li>
#           <a href="//songteksten.net/translations/popular.html">
#            Populairste
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li>
#         <a href="//forum.songteksten.net">
#          Community
#         </a>
#        </li>
#        <li class="dropdown">
#         <a class="dropdown-toggle" data-toggle="dropdown" href="#" role="button">
#          MijnSongteksten
#          <span class="caret">
#          </span>
#         </a>
#         <ul class="dropdown-menu">
#          <li class="separator">
#           <a href="//forum.songteksten.net/index.php?action=login">
#            Inloggen
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#       <form action="/search.html" class="col-sm-3 pull-right hidden-xs hidden-sm form-search" method="get">
#        <div class="input-group">
#         <input class="form-control" name="q" placeholder="Zoeken..." type="text"/>
#         <input name="type[]" type="hidden" value="title"/>
#         <input name="type[]" type="hidden" value="artist"/>
#         <span class="input-group-btn">
#          <button class="btn btn-default" type="submit">
#           Go!
#          </button>
#         </span>
#        </div>
#       </form>
#      </div>
#     </nav>
#     <form action="/search.html" class="visible-xs form-search" method="get">
#      <div class="input-group input-group-lg">
#       <input class="form-control" name="q" placeholder="Zoeken..." type="text"/>
#       <input name="type[]" type="hidden" value="title"/>
#       <input name="type[]" type="hidden" value="artist"/>
#       <span class="input-group-btn">
#        <button class="btn btn-default" type="submit">
#         Go!
#        </button>
#       </span>
#      </div>
#     </form>
#     <div class="header">
#      <a href="/">
#       <img alt="logo songteksten.net" class="logo" src="/img/logo.png"/>
#      </a>
#     </div>
#     <div class="btn-group btn-group-letters">
#      <a class="btn btn-default" href="https://songteksten.net/artists/1.html" title="Bekijk alle artiesten van de letter 1">
#       1
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/2.html" title="Bekijk alle artiesten van de letter 2">
#       2
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/3.html" title="Bekijk alle artiesten van de letter 3">
#       3
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/4.html" title="Bekijk alle artiesten van de letter 4">
#       4
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/5.html" title="Bekijk alle artiesten van de letter 5">
#       5
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/6.html" title="Bekijk alle artiesten van de letter 6">
#       6
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/7.html" title="Bekijk alle artiesten van de letter 7">
#       7
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/8.html" title="Bekijk alle artiesten van de letter 8">
#       8
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/9.html" title="Bekijk alle artiesten van de letter 9">
#       9
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/a.html" title="Bekijk alle artiesten van de letter a">
#       A
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/b.html" title="Bekijk alle artiesten van de letter b">
#       B
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/c.html" title="Bekijk alle artiesten van de letter c">
#       C
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/d.html" title="Bekijk alle artiesten van de letter d">
#       D
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/e.html" title="Bekijk alle artiesten van de letter e">
#       E
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/f.html" title="Bekijk alle artiesten van de letter f">
#       F
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/g.html" title="Bekijk alle artiesten van de letter g">
#       G
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/h.html" title="Bekijk alle artiesten van de letter h">
#       H
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/i.html" title="Bekijk alle artiesten van de letter i">
#       I
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/j.html" title="Bekijk alle artiesten van de letter j">
#       J
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/k.html" title="Bekijk alle artiesten van de letter k">
#       K
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/l.html" title="Bekijk alle artiesten van de letter l">
#       L
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/m.html" title="Bekijk alle artiesten van de letter m">
#       M
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/n.html" title="Bekijk alle artiesten van de letter n">
#       N
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/o.html" title="Bekijk alle artiesten van de letter o">
#       O
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/p.html" title="Bekijk alle artiesten van de letter p">
#       P
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/q.html" title="Bekijk alle artiesten van de letter q">
#       Q
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/r.html" title="Bekijk alle artiesten van de letter r">
#       R
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/s.html" title="Bekijk alle artiesten van de letter s">
#       S
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/t.html" title="Bekijk alle artiesten van de letter t">
#       T
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/u.html" title="Bekijk alle artiesten van de letter u">
#       U
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/v.html" title="Bekijk alle artiesten van de letter v">
#       V
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/w.html" title="Bekijk alle artiesten van de letter w">
#       W
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/x.html" title="Bekijk alle artiesten van de letter x">
#       X
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/y.html" title="Bekijk alle artiesten van de letter y">
#       Y
#      </a>
#      <a class="btn btn-default" href="https://songteksten.net/artists/z.html" title="Bekijk alle artiesten van de letter z">
#       Z
#      </a>
#     </div>
#     <div class="row">
#      <div class="breadcrumb-container col-sm-12">
#       <div class="login-box hidden-xs hidden-sm pull-right col-md-5 col-lg-4">
#        <div class="col-sm-12">
#         <form action="https://forum.songteksten.net?action=login2" class="form-inline form-forum-login pull-right" method="post">
#          <div class="form-group">
#           <input class="form-control input-sm" id="user" name="user" placeholder="Gebruikersnaam" size="18" type="text" value=""/>
#          </div>
#          <div class="form-group">
#           <input class="form-control input-sm" id="passwrd" name="passwrd" placeholder="Wachtwoord" size="18" type="password"/>
#          </div>
#          <div class="form-group">
#           <button class="btn btn-primary btn-sm" type="submit">
#            Inloggen
#           </button>
#          </div>
#         </form>
#        </div>
#       </div>
#       <ol class="breadcrumb">
#        <li>
#         <a href="https://songteksten.net/">
#          Home
#         </a>
#        </li>
#        <li>
#         <a href="https://songteksten.net/artists/e.html">
#          e
#         </a>
#        </li>
#        <li>
#         <a href="https://songteksten.net/artist/lyrics/1938/evanescence.html">
#          Evanescence
#         </a>
#        </li>
#        <li>
#         <a href="https://songteksten.net/artist/lyrics/1938/evanescence.html">
#          Songteksten
#         </a>
#        </li>
#        <li>
#         Bring Me To Life
#        </li>
#       </ol>
#      </div>
#     </div>
#     <div class="flex">
#      <div class="col-sm-12">
#       <div class="row">
#        <div class="col-sm-3 flex-left hidden-xs">
#         <div class="module hidden-xs">
#          <h3>
#           Laatste nieuws
#          </h3>
#          <ul class="list-unstyled">
#           <li>
#            <small class="text-muted">
#             16:42
#            </small>
#            <a href="https://songteksten.net/news/102232/nederlandse-scenarist-wint-amerikaanse-filmprijs.html" title="Nederlandse scenarist wint Amerikaanse filmprijs  (0 reacties)">
#             Nederlandse scenarist wint Amerikaanse filmprijs (0 reacties)
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             16:28
#            </small>
#            <a href="https://songteksten.net/news/102230/broer-aanslagpleger-concert-ariana-grande-net-zo-schuldig.html" title="'Broer aanslagpleger concert Ariana Grande net zo schuldig' (0 reacties)">
#             'Broer aanslagpleger concert Ariana Grande net zo schuldig' (0 reacties)
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             16:26
#            </small>
#            <a href="https://songteksten.net/news/102231/grote-slijmfilm-met-bibi-en-djamila-breekt-records.html" title="Grote Slijmfilm met Bibi en Djamila breekt records (0 reacties)">
#             Grote Slijmfilm met Bibi en Djamila breekt records (0 reacties)
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             15:55
#            </small>
#            <a href="https://songteksten.net/news/102229/anneke-van-giersbergen-nog-steeds-welkom-in-kerk-in-zwolle.html" title="Anneke van Giersbergen nog steeds welkom in kerk in Zwolle (0 reacties)">
#             Anneke van Giersbergen nog steeds welkom in kerk in Zwolle (0 reacties)
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             15:01
#            </small>
#            <a href="https://songteksten.net/news/102228/beach-boys-frontman-roept-op-tot-boycot-beach-boys-concert.html" title="'Beach Boys-frontman' roept op tot boycot Beach Boys-concert (0 reacties)">
#             'Beach Boys-frontman' roept op tot boycot Beach Boys-concert (0 reacties)
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             14:49
#            </small>
#            <a href="https://songteksten.net/news/102227/shannen-doherty-weer-gediagnosticeerd-met-kanker.html" title="Shannen Doherty weer gediagnosticeerd met kanker (0 reacties)">
#             Shannen Doherty weer gediagnosticeerd met kanker (0 reacties)
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             14:38
#            </small>
#            <a href="https://songteksten.net/news/102226/organisatie-we-are-electric-slaat-jaar-over.html" title="Organisatie We Are Electric slaat jaar over (0 reacties)">
#             Organisatie We Are Electric slaat jaar over (0 reacties)
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             13:47
#            </small>
#            <a href="https://songteksten.net/news/102225/marcel-van-roosmalen-verkozen-tot-republikein-van-het-jaar.html" title="Marcel van Roosmalen verkozen tot Republikein van het Jaar (0 reacties)">
#             Marcel van Roosmalen verkozen tot Republikein van het Jaar (0 reacties)
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             13:37
#            </small>
#            <a href="https://songteksten.net/news/102224/veel-annuleringen-bij-meilandjes-na-verhuisbericht.html" title="Veel annuleringen bij Meilandjes na verhuisbericht (0 reacties)">
#             Veel annuleringen bij Meilandjes na verhuisbericht (0 reacties)
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             13:05
#            </small>
#            <a href="https://songteksten.net/news/102223/madonna-biedt-harry-en-meghan-appartement-aan.html" title="Madonna biedt Harry en Meghan appartement aan (0 reacties)">
#             Madonna biedt Harry en Meghan appartement aan (0 reacties)
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="module">
#          <h3>
#           Populairste songteksten
#          </h3>
#          <ul class="list-unstyled">
#           <li>
#            <small class="text-muted">
#             40756
#            </small>
#            <a href="https://songteksten.net/lyric/8601/102664/maan/ze-huilt-maar-ze-lacht.html" title="Ze Huilt Maar Ze Lacht">
#             Ze Huilt Maar Ze Lacht
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/8601/maan.html" title="Maan">
#             Maan
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             10377
#            </small>
#            <a href="https://songteksten.net/lyric/9049/101801/danny-vera/roller-coaster.html" title="Roller Coaster">
#             Roller Coaster
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/9049/danny-vera.html" title="Danny Vera">
#             Danny Vera
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             9976
#            </small>
#            <a href="https://songteksten.net/lyric/9019/102741/snelle/smoorverliefd.html" title="Smoorverliefd">
#             Smoorverliefd
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/9019/snelle.html" title="Snelle">
#             Snelle
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             6459
#            </small>
#            <a href="https://songteksten.net/lyric/9064/102577/rolf-sanchez/pa-olvidarte.html" title="Pa Olvidarte">
#             Pa Olvidarte
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/9064/rolf-sanchez.html" title="Rolf Sanchez">
#             Rolf Sanchez
#            </a>
#            ,
#            <a href="https://songteksten.net/artist/lyrics/9217/emma-heesters.html" title="Emma Heesters">
#             Emma Heesters
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             6181
#            </small>
#            <a href="https://songteksten.net/lyric/9019/102217/snelle/reunie.html" title="Reünie">
#             Reünie
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/9019/snelle.html" title="Snelle">
#             Snelle
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             5733
#            </small>
#            <a href="https://songteksten.net/lyric/60/98333/marco-borsato/mooi.html" title="Mooi">
#             Mooi
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/60/marco-borsato.html" title="Marco Borsato">
#             Marco Borsato
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             5112
#            </small>
#            <a href="https://songteksten.net/lyric/2881/102433/maroon-5/memories.html" title="Memories">
#             Memories
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/2881/maroon-5.html" title="Maroon 5">
#             Maroon 5
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             5085
#            </small>
#            <a href="https://songteksten.net/lyric/9173/102289/tones-and-i/dance-monkey.html" title="Dance Monkey">
#             Dance Monkey
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/9173/tones-and-i.html" title="Tones And I">
#             Tones And I
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             4373
#            </small>
#            <a href="https://songteksten.net/lyric/60/96869/marco-borsato/samen-voor-altijd.html" title="Samen Voor Altijd">
#             Samen Voor Altijd
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/60/marco-borsato.html" title="Marco Borsato">
#             Marco Borsato
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             3294
#            </small>
#            <a href="https://songteksten.net/lyric/2047/31578/nena/99-luftballons.html" title="99 Luftballons">
#             99 Luftballons
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/2047/nena.html" title="Nena">
#             Nena
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="module hidden-xs">
#          <h3>
#           Nieuwste songteksten
#          </h3>
#          <ul class="list-unstyled">
#           <li>
#            <small class="text-muted">
#             11:06
#            </small>
#            <a href="https://songteksten.net/lyric/9247/102765/niks-aan-de-zeis/met-de-trekker-naar-s-gravenhage.html" title="Met de trekker naar 's-Gravenhage">
#             Met de trekker naar 's-Gravenhage
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/9247/niks-aan-de-zeis.html" title="Niks aan de Zeis">
#             Niks aan de Zeis
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             02-02
#            </small>
#            <a href="https://songteksten.net/lyric/3051/102764/samson-en-gert/samson-marie.html" title="Samson &amp; Marie">
#             Samson &amp; Marie
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/3051/samson-en-gert.html" title="Samson En Gert">
#             Samson En Gert
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             28-01
#            </small>
#            <a href="https://songteksten.net/lyric/5943/102763/demi-lovato/anyone.html" title="Anyone">
#             Anyone
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/5943/demi-lovato.html" title="Demi Lovato">
#             Demi Lovato
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             27-01
#            </small>
#            <a href="https://songteksten.net/lyric/8962/102762/merol/slippertje.html" title="Slippertje">
#             Slippertje
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/8962/merol.html" title="MEROL">
#             MEROL
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             25-01
#            </small>
#            <a href="https://songteksten.net/lyric/7419/102761/niels-destadsbader/hoofd-op-mijn-schouder.html" title="Hoofd Op Mijn Schouder">
#             Hoofd Op Mijn Schouder
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/7419/niels-destadsbader.html" title="Niels Destadsbader">
#             Niels Destadsbader
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             21-01
#            </small>
#            <a href="https://songteksten.net/lyric/545/102760/frans-bauer/geen-centen-maar-spullen.html" title="Geen Centen Maar Spullen">
#             Geen Centen Maar Spullen
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/545/frans-bauer.html" title="Frans Bauer">
#             Frans Bauer
#            </a>
#            ,
#            <a href="https://songteksten.net/artist/lyrics/9245/donnie.html" title="Donnie">
#             Donnie
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             21-01
#            </small>
#            <a href="https://songteksten.net/lyric/9173/102759/tones-and-i/never-seen-the-rain.html" title="Never Seen The Rain">
#             Never Seen The Rain
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/9173/tones-and-i.html" title="Tones And I">
#             Tones And I
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             20-01
#            </small>
#            <a href="https://songteksten.net/lyric/8957/102758/billie-eilish/xanny.html" title="xanny">
#             xanny
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/8957/billie-eilish.html" title="Billie Eilish">
#             Billie Eilish
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             20-01
#            </small>
#            <a href="https://songteksten.net/lyric/8941/102757/future/mask-off.html" title="Mask Off">
#             Mask Off
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/8941/future.html" title="Future">
#             Future
#            </a>
#           </li>
#           <li>
#            <small class="text-muted">
#             20-01
#            </small>
#            <a href="https://songteksten.net/lyric/2543/102756/drake/life-is-good.html" title="Life Is Good">
#             Life Is Good
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/2543/drake.html" title="Drake">
#             Drake
#            </a>
#            ,
#            <a href="https://songteksten.net/artist/lyrics/8941/future.html" title="Future">
#             Future
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="module hidden-xs">
#          <h3>
#           Nieuwste albums
#          </h3>
#          <ul class="list-unstyled">
#           <li>
#            <small class="date">
#             25-01
#            </small>
#            <a href="https://songteksten.net/albums/album/7419/2310/niels-destadsbader/boven-de-wolken-fan-editie.html" title="Boven De wolken Fan-Editie 14-02-2020">
#             Boven De wolken Fan-Editie
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/7419/niels-destadsbader.html" title="Niels Destadsbader">
#             Niels Destadsbader
#            </a>
#           </li>
#           <li>
#            <small class="date">
#             02-01
#            </small>
#            <a href="https://songteksten.net/albums/album/7419/2308/niels-destadsbader/boven-de-wolken.html" title="Boven De Wolken 18-10-2019">
#             Boven De Wolken
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/7419/niels-destadsbader.html" title="Niels Destadsbader">
#             Niels Destadsbader
#            </a>
#           </li>
#           <li>
#            <small class="date">
#             02-01
#            </small>
#            <a href="https://songteksten.net/albums/album/7419/2307/niels-destadsbader/dertig.html" title="Dertig 30-05-2018">
#             Dertig
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/7419/niels-destadsbader.html" title="Niels Destadsbader">
#             Niels Destadsbader
#            </a>
#           </li>
#           <li>
#            <small class="date">
#             02-01
#            </small>
#            <a href="https://songteksten.net/albums/album/7419/2306/niels-destadsbader/speeltijd-niels-wiels-editie.html" title="Speeltijd Niels &amp; Wiels editie 17-02-2017">
#             Speeltijd Niels &amp; Wiels editie
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/7419/niels-destadsbader.html" title="Niels Destadsbader">
#             Niels Destadsbader
#            </a>
#           </li>
#           <li>
#            <small class="date">
#             02-01
#            </small>
#            <a href="https://songteksten.net/albums/album/7419/2305/niels-destadsbader/speeltijd.html" title="Speeltijd 21-10-2016">
#             Speeltijd
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/7419/niels-destadsbader.html" title="Niels Destadsbader">
#             Niels Destadsbader
#            </a>
#           </li>
#           <li>
#            <small class="date">
#             12-12
#            </small>
#            <a href="https://songteksten.net/albums/album/7902/2304/kensington/time.html" title="Time 15-11-2019">
#             Time
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/7902/kensington.html" title="Kensington">
#             Kensington
#            </a>
#           </li>
#           <li>
#            <small class="date">
#             24-10
#            </small>
#            <a href="https://songteksten.net/albums/album/7846/2302/tim-akkerman/lions-dont-cry.html" title="Lions Don't Cry 30-11--0001">
#             Lions Don't Cry
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/7846/tim-akkerman.html" title="Tim Akkerman">
#             Tim Akkerman
#            </a>
#           </li>
#           <li>
#            <small class="date">
#             15-07
#            </small>
#            <a href="https://songteksten.net/albums/album/8117/2300/ed-sheeran/no-6-collaborations-project.html" title="No. 6 Collaborations Project 12-07-2019">
#             No. 6 Collaborations Project
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/8117/ed-sheeran.html" title="Ed Sheeran">
#             Ed Sheeran
#            </a>
#           </li>
#           <li>
#            <small class="date">
#             08-07
#            </small>
#            <a href="https://songteksten.net/albums/album/232/2299/rammstein/rammstein.html" title="Rammstein 30-11--0001">
#             Rammstein
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/232/rammstein.html" title="Rammstein">
#             Rammstein
#            </a>
#           </li>
#           <li>
#            <small class="date">
#             05-07
#            </small>
#            <a href="https://songteksten.net/albums/album/4166/2298/earth-wind-and-fire/i-am.html" title="I Am 30-11--0001">
#             I Am
#            </a>
#            -
#            <a href="https://songteksten.net/artist/lyrics/4166/earth-wind-and-fire.html" title="Earth Wind And Fire">
#             Earth Wind And Fire
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="module hidden-xs">
#          <h3>
#           Laatste forumposts
#          </h3>
#          <ul class="list-unstyled forum">
#           <li>
#            <span class="text-muted">
#             18-12
#            </span>
#            <a href="https://forum.songteksten.net/index.php?topic=1327.msg86865;topicseen#new" target="_blank" title="Re: Hoe maak ik een nieuwe artiest aan?">
#             Re: Hoe maak ik een nieuwe artiest aan?
#            </a>
#           </li>
#           <li>
#            <span class="text-muted">
#             08-11
#            </span>
#            <a href="https://forum.songteksten.net/index.php?topic=1327.msg86864;topicseen#new" target="_blank" title="Re: Hoe maak ik een nieuwe artiest aan?">
#             Re: Hoe maak ik een nieuwe artiest aan?
#            </a>
#           </li>
#           <li>
#            <span class="text-muted">
#             11-10
#            </span>
#            <a href="https://forum.songteksten.net/index.php?topic=3543.msg86862;topicseen#new" target="_blank" title="Re: Tante Leen">
#             Re: Tante Leen
#            </a>
#           </li>
#           <li>
#            <span class="text-muted">
#             11-10
#            </span>
#            <a href="https://forum.songteksten.net/index.php?topic=1327.msg86861;topicseen#new" target="_blank" title="Re: Hoe maak ik een nieuwe artiest aan?">
#             Re: Hoe maak ik een nieuwe artiest aan?
#            </a>
#           </li>
#           <li>
#            <span class="text-muted">
#             09-10
#            </span>
#            <a href="https://forum.songteksten.net/index.php?topic=1327.msg86860;topicseen#new" target="_blank" title="Re: Hoe maak ik een nieuwe artiest aan?">
#             Re: Hoe maak ik een nieuwe artiest aan?
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="col-sm-9 flex-right">
#         <div class="row">
#          <div class="col-sm-7 content-left">
#           <h1>
#            Evanescence - Bring Me To Life
#           </h1>
#           how can you see into my eyes
#           <br/>
#           like open doors
#           <br/>
#           leading you down into my core
#           <br/>
#           where I've become so numb without a soul
#           <br/>
#           my spirit sleeping somewhere cold
#           <br/>
#           until you find it there and lead it back home
#           <br/>
#           <br/>
#           (Wake me up)
#           <br/>
#           Wake me up inside
#           <br/>
#           (I can't wake up)
#           <br/>
#           Wake me up inside
#           <br/>
#           (Save me)
#           <br/>
#           call my name and save me from the dark
#           <br/>
#           (Wake me up)
#           <br/>
#           bid my blood to run
#           <br/>
#           (I can't wake up)
#           <br/>
#           before I come undone
#           <br/>
#           (Save me)
#           <br/>
#           save me from the nothing I've become
#           <br/>
#           <br/>
#           now that I know what I'm without
#           <br/>
#           you can't just leave me
#           <br/>
#           breathe into me and make me real
#           <br/>
#           bring me to life
#           <br/>
#           <br/>
#           (Wake me up)
#           <br/>
#           Wake me up inside
#           <br/>
#           (I can't wake up)
#           <br/>
#           Wake me up inside
#           <br/>
#           (Save me)
#           <br/>
#           call my name and save me from the dark
#           <br/>
#           (Wake me up)
#           <br/>
#           bid my blood to run
#           <br/>
#           (I can't wake up)
#           <br/>
#           before I come undone
#           <br/>
#           (Save me)
#           <br/>
#           save me from the nothing I've become
#           <br/>
#           <br/>
#           Bring me to life
#           <br/>
#           (I've been living a lie, there's nothing inside)
#           <br/>
#           Bring me to life
#           <br/>
#           <br/>
#           frozen inside without your touch
#           <br/>
#           without your love darling
#           <br/>
#           only you are the life among the dead
#           <br/>
#           <br/>
#           all this time I can't believe I couldn't see
#           <br/>
#           kept in the dark
#           <br/>
#           but you were there in front of me
#           <br/>
#           I've been sleeping a thousand years it seems
#           <br/>
#           got to open my eyes to everything
#           <br/>
#           without a thought without a voice without a soul
#           <br/>
#           don't let me die here
#           <br/>
#           there must be something more
#           <br/>
#           bring me to life
#           <br/>
#           <br/>
#           (Wake me up)
#           <br/>
#           Wake me up inside
#           <br/>
#           (I can't wake up)
#           <br/>
#           Wake me up inside
#           <br/>
#           (Save me)
#           <br/>
#           call my name and save me from the dark
#           <br/>
#           (Wake me up)
#           <br/>
#           bid my blood to run
#           <br/>
#           (I can't wake up)
#           <br/>
#           before I come undone
#           <br/>
#           (Save me)
#           <br/>
#           save me from the nothing I've become
#           <br/>
#           <br/>
#           (Bring me to life)
#           <br/>
#           I've been living a lie, there's nothing inside
#           <br/>
#           (Bring me to life)
#           <div class="buma-consent" role="alert">
#            <img align="left" alt="FEMU logo" class="img-responsive" src="/img/logo-femu.png"/>
#            Songteksten.net heeft toestemming van Stichting FEMU om deze songtekst te tonen. De songteksten mogen niet anders dan voor prive-gebruik gebruikt worden, iedere andere verspreiding van de songteksten is niet toegestaan.
#           </div>
#          </div>
#          <div class="col-sm-5 content-right">
#           <div id="WA_SONGTEKSTEN_HPA_TOP">
#           </div>
#           <ul class="list-unstyled">
#            <li>
#             <a href="https://songteksten.net/translation/1938/30609/evanescence/bring-me-to-life.html">
#              <span class="glyphicon glyphicon-text-width">
#              </span>
#              Vertaling
#             </a>
#            </li>
#           </ul>
#           <h3>
#            Artiesten
#           </h3>
#           <ul class="list-unstyled">
#            <li>
#             <span class="glyphicon glyphicon-star">
#             </span>
#             <a href="https://songteksten.net/artist/lyrics/1938/evanescence.html">
#              Evanescence
#             </a>
#            </li>
#           </ul>
#           <h3>
#            Statistieken
#           </h3>
#           <ul class="list-unstyled">
#            <li>
#             <span class="glyphicon glyphicon-star">
#             </span>
#             Bekeken: 131
#            </li>
#            <li>
#             <span class="glyphicon glyphicon-star">
#             </span>
#             Toegevoegd
# op: onbekend
#            </li>
#            <li>
#             <span class="glyphicon glyphicon-star">
#             </span>
#             Toegevoegd
# door: onbekend
#            </li>
#            <li>
#             <span class="glyphicon glyphicon-star">
#             </span>
#             Laatst gewijzigd
# op: onbekend
#            </li>
#           </ul>
#           <h3>
#            Toevoegen
#           </h3>
#           <ul class="list-unstyled">
#            <li>
#             <a href="https://songteksten.net/lyric/add/1938.html">
#              <span class="glyphicon glyphicon-plus">
#              </span>
#              Tekst toevoegen
#             </a>
#            </li>
#           </ul>
#           <h3>
#            Albums
#           </h3>
#           <ul class="list-unstyled">
#            <li>
#             <a href="https://songteksten.net/albums/album/1938/344/evanescence/anywhere-but-home.html">
#              <span class="glyphicon glyphicon-cd">
#              </span>
#              Anywhere But Home (22-11-2004)
#             </a>
#            </li>
#            <li>
#             <a href="https://songteksten.net/albums/album/1938/171/evanescence/fallen.html">
#              <span class="glyphicon glyphicon-cd">
#              </span>
#              Fallen (26-01-2004)
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="row">
#          <div class="col-sm-12">
#           <br/>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="col-sm-12">
#       <div data-display="plista_widget_outstream">
#       </div>
#       <script type="text/javascript">
#        (function(c){var g,s,n='script',w=window;w.PLISTA_=w.PLISTA_||[];w.PLISTA_.push(c);if(w.PLISTA_.length>1){return;}g=w.document.getElementsByTagName(n)[0];s=w.document.createElement(n);s.async=true;s.type='text/javascript';s.src=(w.location.protocol==='https:'?'https:':'http:')+'//static'+(c.origin?'-'+c.origin:'')+'.plista.com/async/min.js';g.parentNode.insertBefore(s,g);
#                     }({
#                         "publickey": "c89b4b0dedba7d7e7769023f",
#                         "origin": "nl",
#                         "dataMode": "data-display",
#                         "noCache": true,
#                         "widgets": [
#                             {
#                                 "name": "outstream",
#                                 "pub": {
#                                     "click": "%%CLICK_URL_UNESC%%",
#                                     "impression": "%%VIEW_URL_UNESC%%"
#                                 }
#                             }
#                         ],
#                         "sandbox": %%PREVIEW_MODE%%
#                     }));
#       </script>
#      </div>
#     </div>
#     <footer class="text-center">
#      <a href="https://songteksten.net/adverteren.html">
#       Adverteren
#      </a>
#      |
#      <a href="https://songteksten.net/info/1185/over-ons.html">
#       Over ons
#      </a>
#      |
#      <a href="https://songteksten.net/info/1186/privacy.html">
#       Je privacy
#      </a>
#      |
#      <a href="https://songteksten.net/info/1187/rss-api-functies.html">
#       RSS
#      </a>
#     </footer>
#    </div>
#    <p class="text-copyright text-center">
#     © 2020 - Songteksten.net - Alle rechten voorbehouden.
# - Realisatie:
#     <a href="http://bandhosting.nl" target="_blank">
#      bandhosting.nl
#     </a>
#    </p>
#   </div>
#   <script type="text/javascript">
#    var gaJsHost = (("https:" == document.location.protocol) ? "https://ssl." : "http://www.");
#     document.write(unescape("%3Cscript src='" + gaJsHost + "google-analytics.com/ga.js' type='text/javascript'%3E%3C/script%3E"));
#   </script>
#   <script type="text/javascript">
#    try {
#         var musicopy = _gat._getTracker("UA-68590-1");
#         musicopy._trackPageview();
#     } catch (err) {
#     }
#   </script>
#   <iframe frameborder="no" height="0" src="//images.webads.nl/stir/responsesongteksten_stir.htm" width="0">
#   </iframe>
#   <script>
#    (function (i, s, o, g, r, a, m) {
#         i['GoogleAnalyticsObject'] = r;
#         i[r] = i[r] || function () {
#             (i[r].q = i[r].q || []).push(arguments)
#         }, i[r].l = 1 * new Date();
#         a = s.createElement(o),
#             m = s.getElementsByTagName(o)[0];
#         a.async = 1;
#         a.src = g;
#         m.parentNode.insertBefore(a, m)
#     })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#     ga('set', 'anonymizeIp', true);
#     ga('create', 'UA-68590-10', 'auto');
#     ga('send', 'pageview');
#   </script>
#  </body>
# </html>

# %%
text = soup_lyric_pretty.split('</h1>\n')
print(text[1])
# Out:
#           how can you see into my eyes
#           <br/>
#           like open doors
#           <br/>
#           leading you down into my core
#           <br/>
#           where I've become so numb without a soul
#           <br/>
#           my spirit sleeping somewhere cold
#           <br/>
#           until you find it there and lead it back home
#           <br/>
#           <br/>
#           (Wake me up)
#           <br/>
#           Wake me up inside
#           <br/>
#           (I can't wake up)
#           <br/>
#           Wake me up inside
#           <br/>
#           (Save me)
#           <br/>
#           call my name and save me from the dark
#           <br/>
#           (Wake me up)
#           <br/>
#           bid my blood to run
#           <br/>
#           (I can't wake up)
#           <br/>
#           before I come undone
#           <br/>
#           (Save me)
#           <br/>
#           save me from the nothing I've become
#           <br/>
#           <br/>
#           now that I know what I'm without
#           <br/>
#           you can't just leave me
#           <br/>
#           breathe into me and make me real
#           <br/>
#           bring me to life
#           <br/>
#           <br/>
#           (Wake me up)
#           <br/>
#           Wake me up inside
#           <br/>
#           (I can't wake up)
#           <br/>
#           Wake me up inside
#           <br/>
#           (Save me)
#           <br/>
#           call my name and save me from the dark
#           <br/>
#           (Wake me up)
#           <br/>
#           bid my blood to run
#           <br/>
#           (I can't wake up)
#           <br/>
#           before I come undone
#           <br/>
#           (Save me)
#           <br/>
#           save me from the nothing I've become
#           <br/>
#           <br/>
#           Bring me to life
#           <br/>
#           (I've been living a lie, there's nothing inside)
#           <br/>
#           Bring me to life
#           <br/>
#           <br/>
#           frozen inside without your touch
#           <br/>
#           without your love darling
#           <br/>
#           only you are the life among the dead
#           <br/>
#           <br/>
#           all this time I can't believe I couldn't see
#           <br/>
#           kept in the dark
#           <br/>
#           but you were there in front of me
#           <br/>
#           I've been sleeping a thousand years it seems
#           <br/>
#           got to open my eyes to everything
#           <br/>
#           without a thought without a voice without a soul
#           <br/>
#           don't let me die here
#           <br/>
#           there must be something more
#           <br/>
#           bring me to life
#           <br/>
#           <br/>
#           (Wake me up)
#           <br/>
#           Wake me up inside
#           <br/>
#           (I can't wake up)
#           <br/>
#           Wake me up inside
#           <br/>
#           (Save me)
#           <br/>
#           call my name and save me from the dark
#           <br/>
#           (Wake me up)
#           <br/>
#           bid my blood to run
#           <br/>
#           (I can't wake up)
#           <br/>
#           before I come undone
#           <br/>
#           (Save me)
#           <br/>
#           save me from the nothing I've become
#           <br/>
#           <br/>
#           (Bring me to life)
#           <br/>
#           I've been living a lie, there's nothing inside
#           <br/>
#           (Bring me to life)
#           <div class="buma-consent" role="alert">
#            <img align="left" alt="FEMU logo" class="img-responsive" src="/img/logo-femu.png"/>
#            Songteksten.net heeft toestemming van Stichting FEMU om deze songtekst te tonen. De songteksten mogen niet anders dan voor prive-gebruik gebruikt worden, iedere andere verspreiding van de songteksten is niet toegestaan.
#           </div>
#          </div>
#          <div class="col-sm-5 content-right">
#           <div id="WA_SONGTEKSTEN_HPA_TOP">
#           </div>
#           <ul class="list-unstyled">
#            <li>
#             <a href="https://songteksten.net/translation/1938/30609/evanescence/bring-me-to-life.html">
#              <span class="glyphicon glyphicon-text-width">
#              </span>
#              Vertaling
#             </a>
#            </li>
#           </ul>
#           <h3>
#            Artiesten
#           </h3>
#           <ul class="list-unstyled">
#            <li>
#             <span class="glyphicon glyphicon-star">
#             </span>
#             <a href="https://songteksten.net/artist/lyrics/1938/evanescence.html">
#              Evanescence
#             </a>
#            </li>
#           </ul>
#           <h3>
#            Statistieken
#           </h3>
#           <ul class="list-unstyled">
#            <li>
#             <span class="glyphicon glyphicon-star">
#             </span>
#             Bekeken: 131
#            </li>
#            <li>
#             <span class="glyphicon glyphicon-star">
#             </span>
#             Toegevoegd
# op: onbekend
#            </li>
#            <li>
#             <span class="glyphicon glyphicon-star">
#             </span>
#             Toegevoegd
# door: onbekend
#            </li>
#            <li>
#             <span class="glyphicon glyphicon-star">
#             </span>
#             Laatst gewijzigd
# op: onbekend
#            </li>
#           </ul>
#           <h3>
#            Toevoegen
#           </h3>
#           <ul class="list-unstyled">
#            <li>
#             <a href="https://songteksten.net/lyric/add/1938.html">
#              <span class="glyphicon glyphicon-plus">
#              </span>
#              Tekst toevoegen
#             </a>
#            </li>
#           </ul>
#           <h3>
#            Albums
#           </h3>
#           <ul class="list-unstyled">
#            <li>
#             <a href="https://songteksten.net/albums/album/1938/344/evanescence/anywhere-but-home.html">
#              <span class="glyphicon glyphicon-cd">
#              </span>
#              Anywhere But Home (22-11-2004)
#             </a>
#            </li>
#            <li>
#             <a href="https://songteksten.net/albums/album/1938/171/evanescence/fallen.html">
#              <span class="glyphicon glyphicon-cd">
#              </span>
#              Fallen (26-01-2004)
#             </a>
#            </li>
#           </ul>
#          </div>
#         </div>
#         <div class="row">
#          <div class="col-sm-12">
#           <br/>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="col-sm-12">
#       <div data-display="plista_widget_outstream">
#       </div>
#       <script type="text/javascript">
#        (function(c){var g,s,n='script',w=window;w.PLISTA_=w.PLISTA_||[];w.PLISTA_.push(c);if(w.PLISTA_.length>1){return;}g=w.document.getElementsByTagName(n)[0];s=w.document.createElement(n);s.async=true;s.type='text/javascript';s.src=(w.location.protocol==='https:'?'https:':'http:')+'//static'+(c.origin?'-'+c.origin:'')+'.plista.com/async/min.js';g.parentNode.insertBefore(s,g);
#                     }({
#                         "publickey": "c89b4b0dedba7d7e7769023f",
#                         "origin": "nl",
#                         "dataMode": "data-display",
#                         "noCache": true,
#                         "widgets": [
#                             {
#                                 "name": "outstream",
#                                 "pub": {
#                                     "click": "%%CLICK_URL_UNESC%%",
#                                     "impression": "%%VIEW_URL_UNESC%%"
#                                 }
#                             }
#                         ],
#                         "sandbox": %%PREVIEW_MODE%%
#                     }));
#       </script>
#      </div>
#     </div>
#     <footer class="text-center">
#      <a href="https://songteksten.net/adverteren.html">
#       Adverteren
#      </a>
#      |
#      <a href="https://songteksten.net/info/1185/over-ons.html">
#       Over ons
#      </a>
#      |
#      <a href="https://songteksten.net/info/1186/privacy.html">
#       Je privacy
#      </a>
#      |
#      <a href="https://songteksten.net/info/1187/rss-api-functies.html">
#       RSS
#      </a>
#     </footer>
#    </div>
#    <p class="text-copyright text-center">
#     © 2020 - Songteksten.net - Alle rechten voorbehouden.
# - Realisatie:
#     <a href="http://bandhosting.nl" target="_blank">
#      bandhosting.nl
#     </a>
#    </p>
#   </div>
#   <script type="text/javascript">
#    var gaJsHost = (("https:" == document.location.protocol) ? "https://ssl." : "http://www.");
#     document.write(unescape("%3Cscript src='" + gaJsHost + "google-analytics.com/ga.js' type='text/javascript'%3E%3C/script%3E"));
#   </script>
#   <script type="text/javascript">
#    try {
#         var musicopy = _gat._getTracker("UA-68590-1");
#         musicopy._trackPageview();
#     } catch (err) {
#     }
#   </script>
#   <iframe frameborder="no" height="0" src="//images.webads.nl/stir/responsesongteksten_stir.htm" width="0">
#   </iframe>
#   <script>
#    (function (i, s, o, g, r, a, m) {
#         i['GoogleAnalyticsObject'] = r;
#         i[r] = i[r] || function () {
#             (i[r].q = i[r].q || []).push(arguments)
#         }, i[r].l = 1 * new Date();
#         a = s.createElement(o),
#             m = s.getElementsByTagName(o)[0];
#         a.async = 1;
#         a.src = g;
#         m.parentNode.insertBefore(a, m)
#     })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#     ga('set', 'anonymizeIp', true);
#     ga('create', 'UA-68590-10', 'auto');
#     ga('send', 'pageview');
#   </script>
#  </body>
# </html>

# %%
text = soup_lyric.split('</h1>\n')[1].split('<div class="buma-consent" role="alert">')[0]
text
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-bb4977b585e7> in <module>()
# ----> 1 text = soup_lyric.split('</h1>\n')[1].split('<div class="buma-consent" role="alert">')[0]
#       2 text
#
# TypeError: 'NoneType' object is not callable

# %%
def extract_lyric_from_url(url_lyric):
    """ Extract lyrics after prettify beautiful soup from www.songteksten.nl """
    
    
    # send a http request
    r_lyric = requests.get(url_lyric)
    
    # obtain text with html containt of the url
    html_doc_lyric = r_lyric.text
    
    # making html easier to read
    soup_lyric = BeautifulSoup(html_doc_lyric,,"lxml")

    
    # prettifying it
    soup_lyric_pretty = soup_lyric.prettify()
    
    # Isolating deal that contains the lyric
    
    text = soup_lyric_pretty.split('</h1>\n')[1].split('<div class="buma-consent" role="alert">')[0]

    # Cleaning text and building a list with it
    list_lyrics = text.split('<br/>\n')
    list_lyrics = [item.replace('\n','') for item in list_lyrics]
    list_lyrics = [item.lstrip().rstrip() for item in list_lyrics]
    
    # removing empty elements from the list
    
    for item in list_lyrics:
        if str(item) == '':
            list_lyrics.remove(item)
            
    # this part was added after noticing that at least one lyric was not following the normal pattern
    
    if '<div' in list_lyrics[0]:
        list_lyrics = list_lyrics[1:]
        
        
    # Having the lyrics in string format
    
    lyrics = '. '.join(list_lyrics)
            
    
    # returning both list and string
    
    return list_lyrics, lyrics

# %% [markdown]
# ## Extracting lyric from songteksten.net

# %%
url_lyric = list_links_lyrics_songteksten_net[1]

print(url_lyric,'\n')
# Out:
# https://songteksten.net/lyric/1938/30606/evanescence/breathe-no-more.html

# %%
list_lyrics = extract_lyric_from_url(url_lyric)[0]
list_lyrics
# Out:
# ["I've been looking in the mirror for so long.",
#  "That I've come to believe my soul's on the other side.",
#  'Oh the little pieces falling, shatter.',
#  'Shards of me,',
#  'Too sharp to put back together.',
#  'Too small to matter,',
#  'But big enough to cut me into so many little pieces.',
#  'If I try to touch her,',
#  'And I bleed,',
#  'I bleed,',
#  'And I breathe,',
#  'I breathe no more.',
#  'Take a breath and I try to draw from my spirits well.',
#  'Yet again you refuse to drink like a stubborn child.',
#  'Lie to me,',
#  "Convince me that I've been sick forever.",
#  'And all of this,',
#  'Will make sense when I get better.',
#  'I know the difference,',
#  'Between myself and my reflection.',
#  "I just can't help but to wonder,",
#  'Which of us do you love.',
#  'So I bleed,',
#  'I bleed,',
#  'And I breathe,',
#  'I breathe now...',
#  'Bleed,',
#  'I bleed,',
#  'And I breathe,',
#  'I breathe,',
#  'I breathe-',
#  'I breathe no more.']

# %%
lyrics = extract_lyric_from_url(url_lyric)[1]
lyrics
# Out:
# "I've been looking in the mirror for so long.. That I've come to believe my soul's on the other side.. Oh the little pieces falling, shatter.. Shards of me,. Too sharp to put back together.. Too small to matter,. But big enough to cut me into so many little pieces.. If I try to touch her,. And I bleed,. I bleed,. And I breathe,. I breathe no more.. Take a breath and I try to draw from my spirits well.. Yet again you refuse to drink like a stubborn child.. Lie to me,. Convince me that I've been sick forever.. And all of this,. Will make sense when I get better.. I know the difference,. Between myself and my reflection.. I just can't help but to wonder,. Which of us do you love.. So I bleed,. I bleed,. And I breathe,. I breathe now.... Bleed,. I bleed,. And I breathe,. I breathe,. I breathe-. I breathe no more."

# %% [markdown]
# ### Try another one

# %%
url_lyric = list_links_lyrics_songteksten_net[10]

print(url_lyric)
# Out:
# https://songteksten.net/lyric/1938/77224/evanescence/angel-of-mine.html

# %%
list_lyrics = extract_lyric_from_url(url_lyric)[0]
list_lyrics
# Out:
# ['You are everything I need to see',
#  'Smile and sunlight makes sunlight to me',
#  'Laugh and come and look into me',
#  'Drips of moonlight washing over me',
#  'Can I show you what you are for me',
#  'Angel of mine, let me I thank you',
#  'You have saved me time and time again',
#  'Angel, I must confess',
#  "It's you that always gives me strength",
#  "And I don't know where I'd be without you",
#  'After all these years, one thing is true',
#  'Constant force within my heart is you',
#  "You touch me, I feel I'm moving into you",
#  'I treasure every day I spend with you',
#  'All the things I am come down to you',
#  'Angel of mine',
#  'Let me thank you',
#  'You have saved me time and time again',
#  'Angel, I must confess',
#  "It's you that always gives me strength",
#  "And I don't know where I'd be without you",
#  'Back in the arms of my angel',
#  'Back to the peace that I so love',
#  'Back in the arms of my angel I can finally rest',
#  'Giving you a gift that you remind me']

# %%
lyrics = extract_lyric_from_url(url_lyric)[1]
lyrics
# Out:
# "You are everything I need to see. Smile and sunlight makes sunlight to me. Laugh and come and look into me. Drips of moonlight washing over me. Can I show you what you are for me. Angel of mine, let me I thank you. You have saved me time and time again. Angel, I must confess. It's you that always gives me strength. And I don't know where I'd be without you. After all these years, one thing is true. Constant force within my heart is you. You touch me, I feel I'm moving into you. I treasure every day I spend with you. All the things I am come down to you. Angel of mine. Let me thank you. You have saved me time and time again. Angel, I must confess. It's you that always gives me strength. And I don't know where I'd be without you. Back in the arms of my angel. Back to the peace that I so love. Back in the arms of my angel I can finally rest. Giving you a gift that you remind me"

# %% [markdown]
# It seems to work just fine!
#
# Let's run for all songs and save all strings in a list so we can use to put together with the data we will put together about songs of Evanescence!

# %%
list_lyrics_evanescence = []
list_title_lyrics_evanescence = []

# %%
len(list_links_lyrics_songteksten_net)
# Out:
# 86

# %%
# building lists with titles of lyrics and lyrics

for url_lyric in list_links_lyrics_songteksten_net:
    
    list_title_lyrics_evanescence.append(url_lyric.split('/')[-1].split('.')[-2])
    list_lyrics_evanescence.append(extract_lyric_from_url(url_lyric)[1])

# %% [markdown]
# Just verifying that everything is as expected.

# %%
len(list_title_lyrics_evanescence)
# Out:
# 86

# %%
len(list_lyrics_evanescence)
# Out:
# 86

# %% [markdown]
# Now we create a Pandas data frame with song title and lyrics that will be saved in .csv format for later use.

# %%
# Creating a dataframe with song titles and lyrics

import pandas as pd
df = pd.DataFrame({'song_title': list_title_lyrics_evanescence,
                  'lyrics': list_lyrics_evanescence})

# %%
df.head()
# Out:
#                            song_title  \
# 0  wake-me-up-inside-bring-me-to-life
# 1                     breathe-no-more
# 2                         going-under
# 3                               bleed
# 4                        the-only-one
#
#                                               lyrics
# 0  How can you see into my eyes. Like open doors....
# 1  I've been looking in the mirror for so long.. ...
# 2  now I will tell you what I've done for you. 50...
# 3  How can I pretend that I don't see. What you h...
# 4  When they all come crashing down- midflight. y...

# %% [markdown]
# Before saving this data frame in .csv format for future use let's remove '-' from the song title and make all titles lower case by applying '.lower()'.
#
# By keeping the format of song's title uniform we make our life easier when wanting to add more information about those songs. For instances, some metadata, like album title and year that was recorded.

# %%
df['song_title'] = df['song_title'].apply(lambda x: x.replace('-',' ').lower())

# %%
df.head()
# Out:
#                            song_title  \
# 0  wake me up inside bring me to life
# 1                     breathe no more
# 2                         going under
# 3                               bleed
# 4                        the only one
#
#                                               lyrics
# 0  How can you see into my eyes. Like open doors....
# 1  I've been looking in the mirror for so long.. ...
# 2  now I will tell you what I've done for you. 50...
# 3  How can I pretend that I don't see. What you h...
# 4  When they all come crashing down- midflight. y...

# %%
# saving dataframe to .csv

df.to_csv("./data/lyrics_evanescence.csv", index = False)

# %%
# testing saved .csv

df2 = pd.read_csv("./data/lyrics_evanescence.csv")

df2.head()
# Out:
#                            song_title  \
# 0  wake me up inside bring me to life
# 1                     breathe no more
# 2                         going under
# 3                               bleed
# 4                        the only one
#
#                                               lyrics
# 0  How can you see into my eyes. Like open doors....
# 1  I've been looking in the mirror for so long.. ...
# 2  now I will tell you what I've done for you. 50...
# 3  How can I pretend that I don't see. What you h...
# 4  When they all come crashing down- midflight. y...

# %%
df2.shape
# Out:
# (86, 2)

# %%
del df2

# %% [markdown]
# # **Applying the same to Within Temptation**
#
# Previously, we have tried 4 different lyrics' websites to retrieve Evanescence's lyrics and we have chosen songteksten.net to extract those lyrics.
#
# Some reasons why I chose `songteksten.net`:
#
# 1. When filtering we used `songteksten.net/lyric/number_of_the_artist` and this can be extracted from the url which make easy for us to generalize the code for both or even other bands.
#
# 2. Title of the songs are of the form words separated by '-' which can be easily put in a form to facilitate merging with additional data as we've already planned.
#
# Summarizing, the steps to retrieve lyrics are:
#
# 1. Apply function to retrieve hyperlinks
# 2. Filter out hyperlinks that do not contain lyrics
# 3. Apply function to retrieve hyperlinks (Step 1) to extract lyrics.
#
# And those will be now also applied to retrieve lyrics of Within Temptation.

# %% [markdown]
# ## STEP 1 - Retrieving hyperlinks from songteksten.net

# %%
# retrieving all hyperlinks
urls = ['https://songteksten.net/artist/lyrics/320/within-temptation.html',
       'https://songteksten.net/artist/lyrics/320/within-temptation/page/2.html',
       'https://songteksten.net/artist/lyrics/320/within-temptation/page/3.html']

list_links_lyrics_songteksten_net = []

for url in urls:
    list_links_lyrics_songteksten_net.extend(retrieve_hyperlinks(url))
    
# removing possible duplicates
list_links_lyrics_songteksten_net = list(set(list_links_lyrics_songteksten_net))

    
print('Number of links before filtering:', len(list_links_lyrics_songteksten_net))
# Out:
# Number of links before filtering: 220

# %%
list_links_lyrics_songteksten_net[:10]
# Out:
# ['https://songteksten.net/artists/u.html',
#  'https://songteksten.net/artists/7.html',
#  'https://songteksten.net/lyric/320/24061/within-temptation/world-of-make-believe.html',
#  'https://songteksten.net/artists/j.html',
#  'https://songteksten.net/lyric/2294/46260/leonard-cohen/hallelujah.html',
#  'https://songteksten.net/lyric/320/89805/within-temptation/fire-and-ice.html',
#  'https://songteksten.net/artists/x.html',
#  'https://songteksten.net/lyric/9173/102289/tones-and-i/dance-monkey.html',
#  'https://songteksten.net/adverteren.html',
#  '//songteksten.net/albums/add.html']

# %% [markdown]
# ## STEP 2 - Keeping only hyperlinks of lyrics

# %%
# filtering hyperlinks which contain lyrics - specific for songteksten.net

# using url address to filter lyrics

spliting = urls[0].split('/')
filter_lyrics = spliting[2]+'/lyric/'+spliting[-2]

list_links_lyrics_songteksten_net = [link for link in list_links_lyrics_songteksten_net if (filter_lyrics 
                                                                              in link) ]

print('Number of links after filtering:', len(list_links_lyrics_songteksten_net))
# Out:
# Number of links after filtering: 74

# %%
url_lyric = list_links_lyrics_songteksten_net[1]

print(url_lyric)
# Out:
# https://songteksten.net/lyric/320/89805/within-temptation/fire-and-ice.html

# %% [markdown]
# ## STEP 3 - Extracting song titles and lyrics from lyric's hyperlink

# %%
# lyrics in form of list
list_lyrics = extract_lyric_from_url(url_lyric)[0]
list_lyrics
# Out:
# ["Every word you're saying is a lie",
#  'Run away my dear',
#  'But every sign will say',
#  'Your heart is dead',
#  'Bury all the memories',
#  'Cover them with dirt',
#  "Where's the love we once had",
#  "Our destiny's unsure",
#  "Why can't you see what we had",
#  'Let the fire burn the ice',
#  "Where's the love we once had",
#  'Is it all a lie',
#  'And I still wonder',
#  'Why heaven has died',
#  'The skies are all falling',
#  "I'm breathing but why",
#  'In silence I hold on',
#  'To you and I',
#  'Closer to insantiy',
#  'Buries me alive',
#  "Where's the life we once had",
#  'It cannot be denied',
#  "Why can't you see what we had",
#  'Let the fire burn the ice',
#  "Where's the love we once had",
#  'Is it all a lie',
#  'And I still wonder',
#  'Why heaven has died',
#  'The skies are all falling',
#  "I'm breathing but why",
#  'In silence I hold on',
#  'To you and I',
#  'You run away, you hide away',
#  'To the other side of the universe',
#  "Where you're safe from all that hunts you down",
#  'But the world has gone, where you belong',
#  "And it feels too late so you're moving on",
#  'Can you find your way back home',
#  'And I still wonder',
#  'Why heaven has died',
#  'The skies are all falling',
#  "I'm breathing but why",
#  'In silence I hold on',
#  'To you and I',
#  "Every word you're saying is a lie"]

# %%
# lyrics in form of string

lyrics = extract_lyric_from_url(url_lyric)[1]
lyrics
# Out:
# "Every word you're saying is a lie. Run away my dear. But every sign will say. Your heart is dead. Bury all the memories. Cover them with dirt. Where's the love we once had. Our destiny's unsure. Why can't you see what we had. Let the fire burn the ice. Where's the love we once had. Is it all a lie. And I still wonder. Why heaven has died. The skies are all falling. I'm breathing but why. In silence I hold on. To you and I. Closer to insantiy. Buries me alive. Where's the life we once had. It cannot be denied. Why can't you see what we had. Let the fire burn the ice. Where's the love we once had. Is it all a lie. And I still wonder. Why heaven has died. The skies are all falling. I'm breathing but why. In silence I hold on. To you and I. You run away, you hide away. To the other side of the universe. Where you're safe from all that hunts you down. But the world has gone, where you belong. And it feels too late so you're moving on. Can you find your way back home. And I still wonder. Why heaven has died. The skies are all falling. I'm breathing but why. In silence I hold on. To you and I. Every word you're saying is a lie"

# %% [markdown]
# ## Saving song's titles and lyrics in a .csv file
#
# Just like before we save the result in a .csv to be used in our further analysis.

# %%
# building lists with titles of lyrics and lyrics
list_title_lyrics_within_temptation = []
list_lyrics_within_temptation = []

for url_lyric in list_links_lyrics_songteksten_net:
    
    list_title_lyrics_within_temptation.append(url_lyric.split('/')[-1].split('.')[-2])
    list_lyrics_within_temptation.append(extract_lyric_from_url(url_lyric)[1])

# %%
len(list_title_lyrics_within_temptation)
# Out:
# 74

# %%
len(list_lyrics_within_temptation)
# Out:
# 74

# %%
df = pd.DataFrame({'song_title': list_title_lyrics_within_temptation,
                  'lyrics': list_lyrics_within_temptation})

# %%
# Here we also remove '-' from the title of the songs

df['song_title'] = df['song_title'].apply(lambda x: x.replace('-',' ').lower())

# %%
df.head()
# Out:
#               song_title                                             lyrics
# 0  world of make believe  On golden wings. She flies at night. With her ...
# 1           fire and ice  Every word you're saying is a lie. Run away my...
# 2                  grace  Cold are the bones of thy soldiers. Longing fo...
# 3               overcome  Where are the heroes. I my time of need. Is my...
# 4              somewhere  Lost in the darkness. Hoping for a sign. Inste...

# %%
# saving dataframe to .csv

df.to_csv("./data/lyrics_within_temptation.csv", index = False)

# %%
df2 = pd.read_csv("./data/lyrics_within_temptation.csv")

# %%
df2.head()
# Out:
#               song_title                                             lyrics
# 0  world of make believe  On golden wings. She flies at night. With her ...
# 1           fire and ice  Every word you're saying is a lie. Run away my...
# 2                  grace  Cold are the bones of thy soldiers. Longing fo...
# 3               overcome  Where are the heroes. I my time of need. Is my...
# 4              somewhere  Lost in the darkness. Hoping for a sign. Inste...

# %%
df2.shape
# Out:
# (74, 2)

# %%
del df2
