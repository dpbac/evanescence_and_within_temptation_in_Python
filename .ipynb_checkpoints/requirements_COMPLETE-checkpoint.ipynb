# %% [markdown]
# Choose only the relevants to use in the repository as a .txt file.

# %%
# !pip freeze
# Out:
# absl-py==0.8.0
# astor==0.8.0
# astroid==2.3.1
# astropy==3.2.1
# atomicwrites==1.3.0
# attrs==19.1.0
# backcall==0.1.0
# beautifulsoup4==4.7.1
# bleach==3.1.0
# blis==0.2.4
# bokeh==1.0.4
# boto==2.49.0
# boto3==1.9.111
# botocore==1.12.111
# branca==0.3.1
# bz2file==0.98
# cachetools==3.1.0
# certifi==2018.11.29
# chardet==3.0.4
# Click==7.0
# colorama==0.4.1
# colorlover==0.3.0
# confuse==1.0.0
# cufflinks==0.14.6
# cycler==0.10.0
# cymem==2.0.2
# cytoolz==0.9.0.1
# deap==1.3.0
# decorator==4.3.2
# defusedxml==0.5.0
# docutils==0.14
# en-core-web-sm==2.1.0
# entrypoints==0.3
# folium==0.10.0
# ftfy==4.4.3
# funcy==1.11
# future==0.17.1
# gast==0.2.2
# gensim==3.7.1
# google-pasta==0.1.7
# grpcio==1.24.1
# h5py==2.10.0
# html5lib==1.0.1
# htmlmin==0.1.12
# idna==2.8
# ijson==2.3
# imbalanced-learn==0.4.3
# imblearn==0.0
# ipykernel==5.1.0
# ipython==7.2.0
# ipython-genutils==0.2.0
# ipywidgets==7.4.2
# isort==4.3.21
# jedi==0.13.2
# jellyfish==0.7.2
# Jinja2==2.10
# ...
